# %%
import backtrader as bt
import pandas as pd
import numpy as np
import datetime
from copy import deepcopy

# %% [markdown]
# # 一、读取日度行情表
#
# 表内字段就是 Backtrader 默认情况下要求输入的 7 个字段： 'datetime' 、'open'、'high'、'low'、'close'、'volume'、'openinterest'，外加一个 'sec_code' 股票代码字段。

# %%
daily_price = pd.read_csv("./data/daily_price.csv", parse_dates=['datetime'])
daily_price
# Out:
#          datetime   sec_code        open        high         low       close  \
# 0      2019-01-02  600466.SH   33.064891   33.496709   31.954503   32.386321
# 1      2019-01-02  603228.SH   50.660230   51.458513   50.394136   51.120778
# 2      2019-01-02  600315.SH  148.258423  150.480132  148.258423  149.558935
# 3      2019-01-02  000750.SZ   49.512579   53.154883   48.715825   51.561375
# 4      2019-01-02  002588.SZ   36.608672   36.608672   35.669988   35.763857
# ...           ...        ...         ...         ...         ...         ...
# 255967 2021-01-28  600717.SH  121.489201  122.011736  120.705400  120.966667
# 255968 2021-01-28  300558.SZ  134.155888  137.600704  130.700970  131.569750
# 255969 2021-01-28  600171.SH   39.774873   39.830040   38.864630   38.947380
# 255970 2021-01-28  600597.SH   47.190201   49.243025   46.250355   46.423484
# 255971 2021-01-28  600584.SH  204.725839  210.226650  199.225028  199.799026
#
#            volume  openinterest
# 0        10629352             0
# 1          426147             0
# 2         2138556             0
# 3       227557612             0
# 4         2841517             0
# ...           ...           ...
# 255967    6022213             0
# 255968    5330301             0
# 255969   12354183             0
# 255970   32409940             0
# 255971   68831481             0
#
# [255972 rows x 8 columns]

# %%
# 筛选 600466.SH 和 603228.SH 2只股票的数据集
data1 = daily_price.query(f"sec_code=='600466.SH'").set_index('datetime').drop(columns=['sec_code'])
data2 = daily_price.query(f"sec_code=='603228.SH'").set_index('datetime').drop(columns=['sec_code'])
data2
# Out:
#                  open       high        low      close   volume  openinterest
# datetime
# 2019-01-02  50.660230  51.458513  50.394136  51.120778   426147             0
# 2019-01-03  50.609059  51.049137  50.107573  50.639762   492071             0
# 2019-01-04  50.199683  51.171950  49.278588  50.455543   665486             0
# 2019-01-07  50.864918  51.417575  50.353199  50.967262   689444             0
# 2019-01-08  51.110544  52.174920  50.250855  50.527183   931211             0
# ...               ...        ...        ...        ...      ...           ...
# 2021-01-22  59.955312  59.955312  57.478496  58.174461  6410959             0
# 2021-01-25  58.113052  58.133522  57.110045  57.498966  3445027             0
# 2021-01-26  57.498966  57.498966  54.305716  55.124498  7340180             0
# 2021-01-27  55.595298  55.943280  54.960742  55.595298  2665407             0
# 2021-01-28  55.206376  55.840932  54.612759  54.919803  2372181             0
#
# [506 rows x 6 columns]

# %%
# 导入指标库
import backtrader.indicators as btind # 导入策略分析模块

# %% [markdown]
# # 一、 建议在 __init__() 中提前计算指标

# %%
class MyStrategy(bt.Strategy):
	# 先在 __init__ 中提前算好指标
    def __init__(self):
        sma1 = btind.SimpleMovingAverage(self.data)
        ema1 = btind.ExponentialMovingAverage()
        close_over_sma = self.data.close > sma1
        close_over_ema = self.data.close > ema1
        sma_ema_diff = sma1 - ema1
        # 生成交易信号
        buy_sig = bt.And(close_over_sma, close_over_ema, sma_ema_diff > 0)
    # 在 next 中直接调用计算好的指标
    def next(self):
        if buy_sig:
            self.buy()

# %% [markdown]
# # 二、计算指标时的各种简写形式

# %%
class TestStrategy(bt.Strategy):
    def __init__(self):
        # 最简方式：直接省略指向的数据集
        self.sma1 = btind.SimpleMovingAverage(period=5)
        # 只指定第一个数据表格
        self.sma2 = btind.SMA(self.data, period=5)
        # 指定第一个数据表格的close 线
        self.sma3 = btind.SMA(self.data.close, period=5)
        # 完整写法
        self.sma4 = btind.SMA(self.datas[0].lines[0], period=5)
        # 指标函数也支持简写 SimpleMovingAverage → SMA
        
    def next(self):
        # 提取当前时间点
        print('datetime', self.datas[0].datetime.date(0))
        # 打印当日、昨日、前日的均线
        print('sma1',self.sma1.get(ago=0, size=3))
        print('sma2',self.sma2.get(ago=0, size=3))
        print('sma3',self.sma3.get(ago=0, size=3))
        print('sma4',self.sma4.get(ago=0, size=3))
        
cerebro = bt.Cerebro()
st_date = datetime.datetime(2019,1,2)
end_date = datetime.datetime(2021,1,28)
datafeed1 = bt.feeds.PandasData(dataname=data1, fromdate=st_date, todate=end_date)
cerebro.adddata(datafeed1, name='600466.SH')       
datafeed2 = bt.feeds.PandasData(dataname=data2, fromdate=st_date, todate=end_date)
cerebro.adddata(datafeed2, name='603228.SH')  
cerebro.addstrategy(TestStrategy)
rasult = cerebro.run()
# Out:
# datetime 2019-01-08
# sma1 array('d', [nan, nan, 33.015540696])
# sma2 array('d', [nan, nan, 33.015540696])
# sma3 array('d', [nan, nan, 33.015540696])
# sma4 array('d', [nan, nan, 33.015540696])
# datetime 2019-01-09
# sma1 array('d', [nan, 33.015540696, 33.286968908])
# sma2 array('d', [nan, 33.015540696, 33.286968908])
# sma3 array('d', [nan, 33.015540696, 33.286968908])
# sma4 array('d', [nan, 33.015540696, 33.286968908])
# datetime 2019-01-10
# sma1 array('d', [33.015540696, 33.286968908, 33.62008535])
# sma2 array('d', [33.015540696, 33.286968908, 33.62008535])
# sma3 array('d', [33.015540696, 33.286968908, 33.62008535])
# sma4 array('d', [33.015540696, 33.286968908, 33.62008535])
# datetime 2019-01-11
# sma1 array('d', [33.286968908, 33.62008535, 33.546059473999996])
# sma2 array('d', [33.286968908, 33.62008535, 33.546059473999996])
# sma3 array('d', [33.286968908, 33.62008535, 33.546059473999996])
# sma4 array('d', [33.286968908, 33.62008535, 33.546059473999996])
# datetime 2019-01-14
# sma1 array('d', [33.62008535, 33.546059473999996, 33.323981845999995])
# sma2 array('d', [33.62008535, 33.546059473999996, 33.323981845999995])
# sma3 array('d', [33.62008535, 33.546059473999996, 33.323981845999995])
# sma4 array('d', [33.62008535, 33.546059473999996, 33.323981845999995])
# datetime 2019-01-15
# sma1 array('d', [33.546059473999996, 33.323981845999995, 33.18826774])
# sma2 array('d', [33.546059473999996, 33.323981845999995, 33.18826774])
# sma3 array('d', [33.546059473999996, 33.323981845999995, 33.18826774])
# sma4 array('d', [33.546059473999996, 33.323981845999995, 33.18826774])
# datetime 2019-01-16
# sma1 array('d', [33.323981845999995, 33.18826774, 32.966190112])
# sma2 array('d', [33.323981845999995, 33.18826774, 32.966190112])
# sma3 array('d', [33.323981845999995, 33.18826774, 32.966190112])
# sma4 array('d', [33.323981845999995, 33.18826774, 32.966190112])
# datetime 2019-01-17
# sma1 array('d', [33.18826774, 32.966190112, 32.682424254])
# sma2 array('d', [33.18826774, 32.966190112, 32.682424254])
# sma3 array('d', [33.18826774, 32.966190112, 32.682424254])
# sma4 array('d', [33.18826774, 32.966190112, 32.682424254])
# datetime 2019-01-18
# sma1 array('d', [32.966190112, 32.682424254, 32.608398378])
# sma2 array('d', [32.966190112, 32.682424254, 32.608398378])
# sma3 array('d', [32.966190112, 32.682424254, 32.608398378])
# sma4 array('d', [32.966190112, 32.682424254, 32.608398378])
# datetime 2019-01-21
# sma1 array('d', [32.682424254, 32.608398378, 32.596060732])
# sma2 array('d', [32.682424254, 32.608398378, 32.596060732])
# sma3 array('d', [32.682424254, 32.608398378, 32.596060732])
# sma4 array('d', [32.682424254, 32.608398378, 32.596060732])
# datetime 2019-01-22
# sma1 array('d', [32.608398378, 32.596060732, 32.472684271999995])
# sma2 array('d', [32.608398378, 32.596060732, 32.472684271999995])
# sma3 array('d', [32.608398378, 32.596060732, 32.472684271999995])
# sma4 array('d', [32.608398378, 32.596060732, 32.472684271999995])
# datetime 2019-01-23
# sma1 array('d', [32.596060732, 32.472684271999995, 32.44800898])
# sma2 array('d', [32.596060732, 32.472684271999995, 32.44800898])
# sma3 array('d', [32.596060732, 32.472684271999995, 32.44800898])
# sma4 array('d', [32.596060732, 32.472684271999995, 32.44800898])
# datetime 2019-01-24
# sma1 array('d', [32.472684271999995, 32.44800898, 32.50969721])
# sma2 array('d', [32.472684271999995, 32.44800898, 32.50969721])
# sma3 array('d', [32.472684271999995, 32.44800898, 32.50969721])
# sma4 array('d', [32.472684271999995, 32.44800898, 32.50969721])
# datetime 2019-01-25
# sma1 array('d', [32.44800898, 32.50969721, 32.57138544])
# sma2 array('d', [32.44800898, 32.50969721, 32.57138544])
# sma3 array('d', [32.44800898, 32.50969721, 32.57138544])
# sma4 array('d', [32.44800898, 32.50969721, 32.57138544])
# datetime 2019-01-28
# sma1 array('d', [32.50969721, 32.57138544, 32.855151297999996])
# sma2 array('d', [32.50969721, 32.57138544, 32.855151297999996])
# sma3 array('d', [32.50969721, 32.57138544, 32.855151297999996])
# sma4 array('d', [32.50969721, 32.57138544, 32.855151297999996])
# datetime 2019-01-29
# sma1 array('d', [32.57138544, 32.855151297999996, 33.323981846])
# sma2 array('d', [32.57138544, 32.855151297999996, 33.323981846])
# sma3 array('d', [32.57138544, 32.855151297999996, 33.323981846])
# sma4 array('d', [32.57138544, 32.855151297999996, 33.323981846])
# datetime 2019-01-30
# sma1 array('d', [32.855151297999996, 33.323981846, 33.669435934])
# sma2 array('d', [32.855151297999996, 33.323981846, 33.669435934])
# sma3 array('d', [32.855151297999996, 33.323981846, 33.669435934])
# sma4 array('d', [32.855151297999996, 33.323981846, 33.669435934])
# datetime 2019-01-31
# sma1 array('d', [33.323981846, 33.669435934, 34.039565314])
# sma2 array('d', [33.323981846, 33.669435934, 34.039565314])
# sma3 array('d', [33.323981846, 33.669435934, 34.039565314])
# sma4 array('d', [33.323981846, 33.669435934, 34.039565314])
# datetime 2019-02-01
# sma1 array('d', [33.669435934, 34.039565314, 34.372681756])
# sma2 array('d', [33.669435934, 34.039565314, 34.372681756])
# sma3 array('d', [33.669435934, 34.039565314, 34.372681756])
# sma4 array('d', [33.669435934, 34.039565314, 34.372681756])
# datetime 2019-02-11
# sma1 array('d', [34.039565314, 34.372681756, 34.742811136])
# sma2 array('d', [34.039565314, 34.372681756, 34.742811136])
# sma3 array('d', [34.039565314, 34.372681756, 34.742811136])
# sma4 array('d', [34.039565314, 34.372681756, 34.742811136])
# datetime 2019-02-12
# sma1 array('d', [34.372681756, 34.742811136, 34.91553818])
# sma2 array('d', [34.372681756, 34.742811136, 34.91553818])
# sma3 array('d', [34.372681756, 34.742811136, 34.91553818])
# sma4 array('d', [34.372681756, 34.742811136, 34.91553818])
# datetime 2019-02-13
# sma1 array('d', [34.742811136, 34.91553818, 35.34735579])
# sma2 array('d', [34.742811136, 34.91553818, 35.34735579])
# sma3 array('d', [34.742811136, 34.91553818, 35.34735579])
# sma4 array('d', [34.742811136, 34.91553818, 35.34735579])
# datetime 2019-02-14
# sma1 array('d', [34.91553818, 35.34735579, 35.729822816])
# sma2 array('d', [34.91553818, 35.34735579, 35.729822816])
# sma3 array('d', [34.91553818, 35.34735579, 35.729822816])
# sma4 array('d', [34.91553818, 35.34735579, 35.729822816])
# datetime 2019-02-15
# sma1 array('d', [35.34735579, 35.729822816, 35.766835754])
# sma2 array('d', [35.34735579, 35.729822816, 35.766835754])
# sma3 array('d', [35.34735579, 35.729822816, 35.766835754])
# sma4 array('d', [35.34735579, 35.729822816, 35.766835754])
# datetime 2019-02-18
# sma1 array('d', [35.729822816, 35.766835754, 35.803848691999995])
# sma2 array('d', [35.729822816, 35.766835754, 35.803848691999995])
# sma3 array('d', [35.729822816, 35.766835754, 35.803848691999995])
# sma4 array('d', [35.729822816, 35.766835754, 35.803848691999995])
# datetime 2019-02-19
# sma1 array('d', [35.766835754, 35.803848691999995, 35.692809878000006])
# sma2 array('d', [35.766835754, 35.803848691999995, 35.692809878000006])
# sma3 array('d', [35.766835754, 35.803848691999995, 35.692809878000006])
# sma4 array('d', [35.766835754, 35.803848691999995, 35.692809878000006])
# datetime 2019-02-20
# sma1 array('d', [35.803848691999995, 35.692809878000006, 35.495407541999995])
# sma2 array('d', [35.803848691999995, 35.692809878000006, 35.495407541999995])
# sma3 array('d', [35.803848691999995, 35.692809878000006, 35.495407541999995])
# sma4 array('d', [35.803848691999995, 35.692809878000006, 35.495407541999995])
# datetime 2019-02-21
# sma1 array('d', [35.692809878000006, 35.495407541999995, 35.236316976])
# sma2 array('d', [35.692809878000006, 35.495407541999995, 35.236316976])
# sma3 array('d', [35.692809878000006, 35.495407541999995, 35.236316976])
# sma4 array('d', [35.692809878000006, 35.495407541999995, 35.236316976])
# datetime 2019-02-22
# sma1 array('d', [35.495407541999995, 35.236316976, 35.28566756])
# sma2 array('d', [35.495407541999995, 35.236316976, 35.28566756])
# sma3 array('d', [35.495407541999995, 35.236316976, 35.28566756])
# sma4 array('d', [35.495407541999995, 35.236316976, 35.28566756])
# datetime 2019-02-25
# sma1 array('d', [35.236316976, 35.28566756, 35.507745188])
# sma2 array('d', [35.236316976, 35.28566756, 35.507745188])
# sma3 array('d', [35.236316976, 35.28566756, 35.507745188])
# sma4 array('d', [35.236316976, 35.28566756, 35.507745188])
# datetime 2019-02-26
# sma1 array('d', [35.28566756, 35.507745188, 36.038263966])
# sma2 array('d', [35.28566756, 35.507745188, 36.038263966])
# sma3 array('d', [35.28566756, 35.507745188, 36.038263966])
# sma4 array('d', [35.28566756, 35.507745188, 36.038263966])
# datetime 2019-02-27
# sma1 array('d', [35.507745188, 36.038263966, 36.655146265999996])
# sma2 array('d', [35.507745188, 36.038263966, 36.655146265999996])
# sma3 array('d', [35.507745188, 36.038263966, 36.655146265999996])
# sma4 array('d', [35.507745188, 36.038263966, 36.655146265999996])
# datetime 2019-02-28
# sma1 array('d', [36.038263966, 36.655146265999996, 37.346054442])
# sma2 array('d', [36.038263966, 36.655146265999996, 37.346054442])
# sma3 array('d', [36.038263966, 36.655146265999996, 37.346054442])
# sma4 array('d', [36.038263966, 36.655146265999996, 37.346054442])
# datetime 2019-03-01
# sma1 array('d', [36.655146265999996, 37.346054442, 38.036962618000004])
# sma2 array('d', [36.655146265999996, 37.346054442, 38.036962618000004])
# sma3 array('d', [36.655146265999996, 37.346054442, 38.036962618000004])
# sma4 array('d', [36.655146265999996, 37.346054442, 38.036962618000004])
# datetime 2019-03-04
# sma1 array('d', [37.346054442, 38.036962618000004, 38.468780228])
# sma2 array('d', [37.346054442, 38.036962618000004, 38.468780228])
# sma3 array('d', [37.346054442, 38.036962618000004, 38.468780228])
# sma4 array('d', [37.346054442, 38.036962618000004, 38.468780228])
# datetime 2019-03-05
# sma1 array('d', [38.036962618000004, 38.468780228, 39.295402509999995])
# sma2 array('d', [38.036962618000004, 38.468780228, 39.295402509999995])
# sma3 array('d', [38.036962618000004, 38.468780228, 39.295402509999995])
# sma4 array('d', [38.036962618000004, 38.468780228, 39.295402509999995])
# datetime 2019-03-06
# sma1 array('d', [38.468780228, 39.295402509999995, 40.047998916])
# sma2 array('d', [38.468780228, 39.295402509999995, 40.047998916])
# sma3 array('d', [38.468780228, 39.295402509999995, 40.047998916])
# sma4 array('d', [38.468780228, 39.295402509999995, 40.047998916])
# datetime 2019-03-07
# sma1 array('d', [39.295402509999995, 40.047998916, 40.677218862000004])
# sma2 array('d', [39.295402509999995, 40.047998916, 40.677218862000004])
# sma3 array('d', [39.295402509999995, 40.047998916, 40.677218862000004])
# sma4 array('d', [39.295402509999995, 40.047998916, 40.677218862000004])
# datetime 2019-03-08
# sma1 array('d', [40.047998916, 40.677218862000004, 40.664881216000005])
# sma2 array('d', [40.047998916, 40.677218862000004, 40.664881216000005])
# sma3 array('d', [40.047998916, 40.677218862000004, 40.664881216000005])
# sma4 array('d', [40.047998916, 40.677218862000004, 40.664881216000005])
# datetime 2019-03-11
# sma1 array('d', [40.677218862000004, 40.664881216000005, 40.677218862000004])
# sma2 array('d', [40.677218862000004, 40.664881216000005, 40.677218862000004])
# sma3 array('d', [40.677218862000004, 40.664881216000005, 40.677218862000004])
# sma4 array('d', [40.677218862000004, 40.664881216000005, 40.677218862000004])
# datetime 2019-03-12
# sma1 array('d', [40.664881216000005, 40.677218862000004, 40.40579065])
# sma2 array('d', [40.664881216000005, 40.677218862000004, 40.40579065])
# sma3 array('d', [40.664881216000005, 40.677218862000004, 40.40579065])
# sma4 array('d', [40.664881216000005, 40.677218862000004, 40.40579065])
# datetime 2019-03-13
# sma1 array('d', [40.677218862000004, 40.40579065, 40.418128296000006])
# sma2 array('d', [40.677218862000004, 40.40579065, 40.418128296000006])
# sma3 array('d', [40.677218862000004, 40.40579065, 40.418128296000006])
# sma4 array('d', [40.677218862000004, 40.40579065, 40.418128296000006])
# datetime 2019-03-14
# sma1 array('d', [40.40579065, 40.418128296000006, 40.368777712])
# sma2 array('d', [40.40579065, 40.418128296000006, 40.368777712])
# sma3 array('d', [40.40579065, 40.418128296000006, 40.368777712])
# sma4 array('d', [40.40579065, 40.418128296000006, 40.368777712])
# datetime 2019-03-15
# sma1 array('d', [40.418128296000006, 40.368777712, 41.183062348])
# sma2 array('d', [40.418128296000006, 40.368777712, 41.183062348])
# sma3 array('d', [40.418128296000006, 40.368777712, 41.183062348])
# sma4 array('d', [40.418128296000006, 40.368777712, 41.183062348])
# datetime 2019-03-18
# sma1 array('d', [40.368777712, 41.183062348, 42.231762258])
# sma2 array('d', [40.368777712, 41.183062348, 42.231762258])
# sma3 array('d', [40.368777712, 41.183062348, 42.231762258])
# sma4 array('d', [40.368777712, 41.183062348, 42.231762258])
# datetime 2019-03-19
# sma1 array('d', [41.183062348, 42.231762258, 43.046046894])
# sma2 array('d', [41.183062348, 42.231762258, 43.046046894])
# sma3 array('d', [41.183062348, 42.231762258, 43.046046894])
# sma4 array('d', [41.183062348, 42.231762258, 43.046046894])
# datetime 2019-03-20
# sma1 array('d', [42.231762258, 43.046046894, 43.527215088000005])
# sma2 array('d', [42.231762258, 43.046046894, 43.527215088000005])
# sma3 array('d', [42.231762258, 43.046046894, 43.527215088000005])
# sma4 array('d', [42.231762258, 43.046046894, 43.527215088000005])
# datetime 2019-03-21
# sma1 array('d', [43.046046894, 43.527215088000005, 44.514226768])
# sma2 array('d', [43.046046894, 43.527215088000005, 44.514226768])
# sma3 array('d', [43.046046894, 43.527215088000005, 44.514226768])
# sma4 array('d', [43.046046894, 43.527215088000005, 44.514226768])
# datetime 2019-03-22
# sma1 array('d', [43.527215088000005, 44.514226768, 45.131109068])
# sma2 array('d', [43.527215088000005, 44.514226768, 45.131109068])
# sma3 array('d', [43.527215088000005, 44.514226768, 45.131109068])
# sma4 array('d', [43.527215088000005, 44.514226768, 45.131109068])
# datetime 2019-03-25
# sma1 array('d', [44.514226768, 45.131109068, 45.365524342])
# sma2 array('d', [44.514226768, 45.131109068, 45.365524342])
# sma3 array('d', [44.514226768, 45.131109068, 45.365524342])
# sma4 array('d', [44.514226768, 45.131109068, 45.365524342])
# datetime 2019-03-26
# sma1 array('d', [45.131109068, 45.365524342, 45.340849049999996])
# sma2 array('d', [45.131109068, 45.365524342, 45.340849049999996])
# sma3 array('d', [45.131109068, 45.365524342, 45.340849049999996])
# sma4 array('d', [45.131109068, 45.365524342, 45.340849049999996])
# datetime 2019-03-27
# sma1 array('d', [45.365524342, 45.340849049999996, 45.513576094])
# sma2 array('d', [45.365524342, 45.340849049999996, 45.513576094])
# sma3 array('d', [45.365524342, 45.340849049999996, 45.513576094])
# sma4 array('d', [45.365524342, 45.340849049999996, 45.513576094])
# datetime 2019-03-28
# sma1 array('d', [45.340849049999996, 45.513576094, 44.983057316])
# sma2 array('d', [45.340849049999996, 45.513576094, 44.983057316])
# sma3 array('d', [45.340849049999996, 45.513576094, 44.983057316])
# sma4 array('d', [45.340849049999996, 45.513576094, 44.983057316])
# datetime 2019-03-29
# sma1 array('d', [45.513576094, 44.983057316, 44.946044377999996])
# sma2 array('d', [45.513576094, 44.983057316, 44.946044377999996])
# sma3 array('d', [45.513576094, 44.983057316, 44.946044377999996])
# sma4 array('d', [45.513576094, 44.983057316, 44.946044377999996])
# datetime 2019-04-01
# sma1 array('d', [44.983057316, 44.946044377999996, 45.365524342])
# sma2 array('d', [44.983057316, 44.946044377999996, 45.365524342])
# sma3 array('d', [44.983057316, 44.946044377999996, 45.365524342])
# sma4 array('d', [44.983057316, 44.946044377999996, 45.365524342])
# datetime 2019-04-02
# sma1 array('d', [44.946044377999996, 45.365524342, 45.95773135])
# sma2 array('d', [44.946044377999996, 45.365524342, 45.95773135])
# sma3 array('d', [44.946044377999996, 45.365524342, 45.95773135])
# sma4 array('d', [44.946044377999996, 45.365524342, 45.95773135])
# datetime 2019-04-03
# sma1 array('d', [45.365524342, 45.95773135, 46.475912482])
# sma2 array('d', [45.365524342, 45.95773135, 46.475912482])
# sma3 array('d', [45.365524342, 45.95773135, 46.475912482])
# sma4 array('d', [45.365524342, 45.95773135, 46.475912482])
# datetime 2019-04-04
# sma1 array('d', [45.95773135, 46.475912482, 47.401235932])
# sma2 array('d', [45.95773135, 46.475912482, 47.401235932])
# sma3 array('d', [45.95773135, 46.475912482, 47.401235932])
# sma4 array('d', [45.95773135, 46.475912482, 47.401235932])
# datetime 2019-04-08
# sma1 array('d', [46.475912482, 47.401235932, 47.796040604])
# sma2 array('d', [46.475912482, 47.401235932, 47.796040604])
# sma3 array('d', [46.475912482, 47.401235932, 47.796040604])
# sma4 array('d', [46.475912482, 47.401235932, 47.796040604])
# datetime 2019-04-09
# sma1 array('d', [47.401235932, 47.796040604, 48.684351116])
# sma2 array('d', [47.401235932, 47.796040604, 48.684351116])
# sma3 array('d', [47.401235932, 47.796040604, 48.684351116])
# sma4 array('d', [47.401235932, 47.796040604, 48.684351116])
# datetime 2019-04-10
# sma1 array('d', [47.796040604, 48.684351116, 49.288895769999996])
# sma2 array('d', [47.796040604, 48.684351116, 49.288895769999996])
# sma3 array('d', [47.796040604, 48.684351116, 49.288895769999996])
# sma4 array('d', [47.796040604, 48.684351116, 49.288895769999996])
# datetime 2019-04-11
# sma1 array('d', [48.684351116, 49.288895769999996, 49.399934584])
# sma2 array('d', [48.684351116, 49.288895769999996, 49.399934584])
# sma3 array('d', [48.684351116, 49.288895769999996, 49.399934584])
# sma4 array('d', [48.684351116, 49.288895769999996, 49.399934584])
# datetime 2019-04-12
# sma1 array('d', [49.288895769999996, 49.399934584, 49.486298106])
# sma2 array('d', [49.288895769999996, 49.399934584, 49.486298106])
# sma3 array('d', [49.288895769999996, 49.399934584, 49.486298106])
# sma4 array('d', [49.288895769999996, 49.399934584, 49.486298106])
# datetime 2019-04-15
# sma1 array('d', [49.399934584, 49.486298106, 49.584999274])
# sma2 array('d', [49.399934584, 49.486298106, 49.584999274])
# sma3 array('d', [49.399934584, 49.486298106, 49.584999274])
# sma4 array('d', [49.399934584, 49.486298106, 49.584999274])
# datetime 2019-04-16
# sma1 array('d', [49.486298106, 49.584999274, 48.474611134])
# sma2 array('d', [49.486298106, 49.584999274, 48.474611134])
# sma3 array('d', [49.486298106, 49.584999274, 48.474611134])
# sma4 array('d', [49.486298106, 49.584999274, 48.474611134])
# datetime 2019-04-17
# sma1 array('d', [49.584999274, 48.474611134, 47.610975914])
# sma2 array('d', [49.584999274, 48.474611134, 47.610975914])
# sma3 array('d', [49.584999274, 48.474611134, 47.610975914])
# sma4 array('d', [49.584999274, 48.474611134, 47.610975914])
# datetime 2019-04-18
# sma1 array('d', [48.474611134, 47.610975914, 46.833704216])
# sma2 array('d', [48.474611134, 47.610975914, 46.833704216])
# sma3 array('d', [48.474611134, 47.610975914, 46.833704216])
# sma4 array('d', [48.474611134, 47.610975914, 46.833704216])
# datetime 2019-04-19
# sma1 array('d', [47.610975914, 46.833704216, 46.216821916])
# sma2 array('d', [47.610975914, 46.833704216, 46.216821916])
# sma3 array('d', [47.610975914, 46.833704216, 46.216821916])
# sma4 array('d', [47.610975914, 46.833704216, 46.216821916])
# datetime 2019-04-22
# sma1 array('d', [46.833704216, 46.216821916, 45.168122006])
# sma2 array('d', [46.833704216, 46.216821916, 45.168122006])
# sma3 array('d', [46.833704216, 46.216821916, 45.168122006])
# sma4 array('d', [46.833704216, 46.216821916, 45.168122006])
# datetime 2019-04-23
# sma1 array('d', [46.216821916, 45.168122006, 44.427863246])
# sma2 array('d', [46.216821916, 45.168122006, 44.427863246])
# sma3 array('d', [46.216821916, 45.168122006, 44.427863246])
# sma4 array('d', [46.216821916, 45.168122006, 44.427863246])
# datetime 2019-04-24
# sma1 array('d', [45.168122006, 44.427863246, 43.786305654])
# sma2 array('d', [45.168122006, 44.427863246, 43.786305654])
# sma3 array('d', [45.168122006, 44.427863246, 43.786305654])
# sma4 array('d', [45.168122006, 44.427863246, 43.786305654])
# datetime 2019-04-25
# sma1 array('d', [44.427863246, 43.786305654, 43.354488044])
# sma2 array('d', [44.427863246, 43.786305654, 43.354488044])
# sma3 array('d', [44.427863246, 43.786305654, 43.354488044])
# sma4 array('d', [44.427863246, 43.786305654, 43.354488044])
# datetime 2019-04-26
# sma1 array('d', [43.786305654, 43.354488044, 42.860982203999995])
# sma2 array('d', [43.786305654, 43.354488044, 42.860982203999995])
# sma3 array('d', [43.786305654, 43.354488044, 42.860982203999995])
# sma4 array('d', [43.786305654, 43.354488044, 42.860982203999995])
# datetime 2019-04-29
# sma1 array('d', [43.354488044, 42.860982203999995, 42.984358664])
# sma2 array('d', [43.354488044, 42.860982203999995, 42.984358664])
# sma3 array('d', [43.354488044, 42.860982203999995, 42.984358664])
# sma4 array('d', [43.354488044, 42.860982203999995, 42.984358664])
# datetime 2019-04-30
# sma1 array('d', [42.860982203999995, 42.984358664, 42.984358664])
# sma2 array('d', [42.860982203999995, 42.984358664, 42.984358664])
# sma3 array('d', [42.860982203999995, 42.984358664, 42.984358664])
# sma4 array('d', [42.860982203999995, 42.984358664, 42.984358664])
# datetime 2019-05-06
# sma1 array('d', [42.984358664, 42.984358664, 42.120723444])
# sma2 array('d', [42.984358664, 42.984358664, 42.120723444])
# sma3 array('d', [42.984358664, 42.984358664, 42.120723444])
# sma4 array('d', [42.984358664, 42.984358664, 42.120723444])
# datetime 2019-05-07
# sma1 array('d', [42.984358664, 42.120723444, 41.614879958])
# sma2 array('d', [42.984358664, 42.120723444, 41.614879958])
# sma3 array('d', [42.984358664, 42.120723444, 41.614879958])
# sma4 array('d', [42.984358664, 42.120723444, 41.614879958])
# datetime 2019-05-08
# sma1 array('d', [42.120723444, 41.614879958, 41.047348196])
# sma2 array('d', [42.120723444, 41.614879958, 41.047348196])
# sma3 array('d', [42.120723444, 41.614879958, 41.047348196])
# sma4 array('d', [42.120723444, 41.614879958, 41.047348196])
# datetime 2019-05-09
# sma1 array('d', [41.614879958, 41.047348196, 40.41864145])
# sma2 array('d', [41.614879958, 41.047348196, 40.41864145])
# sma3 array('d', [41.614879958, 41.047348196, 40.41864145])
# sma4 array('d', [41.614879958, 41.047348196, 40.41864145])
# datetime 2019-05-10
# sma1 array('d', [41.047348196, 40.41864145, 40.056210713999995])
# sma2 array('d', [41.047348196, 40.41864145, 40.056210713999995])
# sma3 array('d', [41.047348196, 40.41864145, 40.056210713999995])
# sma4 array('d', [41.047348196, 40.41864145, 40.056210713999995])
# datetime 2019-05-13
# sma1 array('d', [40.41864145, 40.056210713999995, 40.31324825])
# sma2 array('d', [40.41864145, 40.056210713999995, 40.31324825])
# sma3 array('d', [40.41864145, 40.056210713999995, 40.31324825])
# sma4 array('d', [40.41864145, 40.056210713999995, 40.31324825])
# datetime 2019-05-14
# sma1 array('d', [40.056210713999995, 40.31324825, 40.184739284])
# sma2 array('d', [40.056210713999995, 40.31324825, 40.184739284])
# sma3 array('d', [40.056210713999995, 40.31324825, 40.184739284])
# sma4 array('d', [40.056210713999995, 40.31324825, 40.184739284])
# datetime 2019-05-15
# sma1 array('d', [40.31324825, 40.184739284, 40.22329196])
# sma2 array('d', [40.31324825, 40.184739284, 40.22329196])
# sma3 array('d', [40.31324825, 40.184739284, 40.22329196])
# sma4 array('d', [40.31324825, 40.184739284, 40.22329196])
# datetime 2019-05-16
# sma1 array('d', [40.184739284, 40.22329196, 40.300397312])
# sma2 array('d', [40.184739284, 40.22329196, 40.300397312])
# sma3 array('d', [40.184739284, 40.22329196, 40.300397312])
# sma4 array('d', [40.184739284, 40.22329196, 40.300397312])
# datetime 2019-05-17
# sma1 array('d', [40.22329196, 40.300397312, 40.069081256000004])
# sma2 array('d', [40.22329196, 40.300397312, 40.069081256000004])
# sma3 array('d', [40.22329196, 40.300397312, 40.069081256000004])
# sma4 array('d', [40.22329196, 40.300397312, 40.069081256000004])
# datetime 2019-05-20
# sma1 array('d', [40.300397312, 40.069081256000004, 39.96627412])
# sma2 array('d', [40.300397312, 40.069081256000004, 39.96627412])
# sma3 array('d', [40.300397312, 40.069081256000004, 39.96627412])
# sma4 array('d', [40.300397312, 40.069081256000004, 39.96627412])
# datetime 2019-05-21
# sma1 array('d', [40.069081256000004, 39.96627412, 40.056230364])
# sma2 array('d', [40.069081256000004, 39.96627412, 40.056230364])
# sma3 array('d', [40.069081256000004, 39.96627412, 40.056230364])
# sma4 array('d', [40.069081256000004, 39.96627412, 40.056230364])
# datetime 2019-05-22
# sma1 array('d', [39.96627412, 40.056230364, 39.863466984])
# sma2 array('d', [39.96627412, 40.056230364, 39.863466984])
# sma3 array('d', [39.96627412, 40.056230364, 39.863466984])
# sma4 array('d', [39.96627412, 40.056230364, 39.863466984])
# datetime 2019-05-23
# sma1 array('d', [40.056230364, 39.863466984, 39.465089332000005])
# sma2 array('d', [40.056230364, 39.863466984, 39.465089332000005])
# sma3 array('d', [40.056230364, 39.863466984, 39.465089332000005])
# sma4 array('d', [40.056230364, 39.863466984, 39.465089332000005])
# datetime 2019-05-24
# sma1 array('d', [39.863466984, 39.465089332000005, 38.976755436000005])
# sma2 array('d', [39.863466984, 39.465089332000005, 38.976755436000005])
# sma3 array('d', [39.863466984, 39.465089332000005, 38.976755436000005])
# sma4 array('d', [39.863466984, 39.465089332000005, 38.976755436000005])
# datetime 2019-05-27
# sma1 array('d', [39.465089332000005, 38.976755436000005, 38.783992056])
# sma2 array('d', [39.465089332000005, 38.976755436000005, 38.783992056])
# sma3 array('d', [39.465089332000005, 38.976755436000005, 38.783992056])
# sma4 array('d', [39.465089332000005, 38.976755436000005, 38.783992056])
# datetime 2019-05-28
# sma1 array('d', [38.976755436000005, 38.783992056, 38.50127243199999])
# sma2 array('d', [38.976755436000005, 38.783992056, 38.50127243199999])
# sma3 array('d', [38.976755436000005, 38.783992056, 38.50127243199999])
# sma4 array('d', [38.976755436000005, 38.783992056, 38.50127243199999])
# datetime 2019-05-29
# sma1 array('d', [38.783992056, 38.50127243199999, 38.205701915999995])
# sma2 array('d', [38.783992056, 38.50127243199999, 38.205701915999995])
# sma3 array('d', [38.783992056, 38.50127243199999, 38.205701915999995])
# sma4 array('d', [38.783992056, 38.50127243199999, 38.205701915999995])
# datetime 2019-05-30
# sma1 array('d', [38.50127243199999, 38.205701915999995, 38.090043888])
# sma2 array('d', [38.50127243199999, 38.205701915999995, 38.090043888])
# sma3 array('d', [38.50127243199999, 38.205701915999995, 38.090043888])
# sma4 array('d', [38.50127243199999, 38.205701915999995, 38.090043888])
# datetime 2019-05-31
# sma1 array('d', [38.205701915999995, 38.090043888, 38.192851024])
# sma2 array('d', [38.205701915999995, 38.090043888, 38.192851024])
# sma3 array('d', [38.205701915999995, 38.090043888, 38.192851024])
# sma4 array('d', [38.205701915999995, 38.090043888, 38.192851024])
# datetime 2019-06-03
# sma1 array('d', [38.090043888, 38.192851024, 38.051491211999995])
# sma2 array('d', [38.090043888, 38.192851024, 38.051491211999995])
# sma3 array('d', [38.090043888, 38.192851024, 38.051491211999995])
# sma4 array('d', [38.090043888, 38.192851024, 38.051491211999995])
# datetime 2019-06-04
# sma1 array('d', [38.192851024, 38.051491211999995, 37.678815344])
# sma2 array('d', [38.192851024, 38.051491211999995, 37.678815344])
# sma3 array('d', [38.192851024, 38.051491211999995, 37.678815344])
# sma4 array('d', [38.192851024, 38.051491211999995, 37.678815344])
# datetime 2019-06-05
# sma1 array('d', [38.051491211999995, 37.678815344, 37.601709991999996])
# sma2 array('d', [38.051491211999995, 37.678815344, 37.601709991999996])
# sma3 array('d', [38.051491211999995, 37.678815344, 37.601709991999996])
# sma4 array('d', [38.051491211999995, 37.678815344, 37.601709991999996])
# datetime 2019-06-06
# sma1 array('d', [37.678815344, 37.601709991999996, 37.318990368])
# sma2 array('d', [37.678815344, 37.601709991999996, 37.318990368])
# sma3 array('d', [37.678815344, 37.601709991999996, 37.318990368])
# sma4 array('d', [37.678815344, 37.601709991999996, 37.318990368])
# datetime 2019-06-10
# sma1 array('d', [37.601709991999996, 37.318990368, 37.306139476])
# sma2 array('d', [37.601709991999996, 37.318990368, 37.306139476])
# sma3 array('d', [37.601709991999996, 37.318990368, 37.306139476])
# sma4 array('d', [37.601709991999996, 37.318990368, 37.306139476])
# datetime 2019-06-11
# sma1 array('d', [37.318990368, 37.306139476, 37.755920696])
# sma2 array('d', [37.318990368, 37.306139476, 37.755920696])
# sma3 array('d', [37.318990368, 37.306139476, 37.755920696])
# sma4 array('d', [37.318990368, 37.306139476, 37.755920696])
# datetime 2019-06-12
# sma1 array('d', [37.306139476, 37.755920696, 38.411316188])
# sma2 array('d', [37.306139476, 37.755920696, 38.411316188])
# sma3 array('d', [37.306139476, 37.755920696, 38.411316188])
# sma4 array('d', [37.306139476, 37.755920696, 38.411316188])
# datetime 2019-06-13
# sma1 array('d', [37.755920696, 38.411316188, 38.861097408])
# sma2 array('d', [37.755920696, 38.411316188, 38.861097408])
# sma3 array('d', [37.755920696, 38.411316188, 38.861097408])
# sma4 array('d', [37.755920696, 38.411316188, 38.861097408])
# datetime 2019-06-14
# sma1 array('d', [38.411316188, 38.861097408, 39.722107172])
# sma2 array('d', [38.411316188, 38.861097408, 39.722107172])
# sma3 array('d', [38.411316188, 38.861097408, 39.722107172])
# sma4 array('d', [38.411316188, 38.861097408, 39.722107172])
# datetime 2019-06-17
# sma1 array('d', [38.861097408, 39.722107172, 40.236142852])
# sma2 array('d', [38.861097408, 39.722107172, 40.236142852])
# sma3 array('d', [38.861097408, 39.722107172, 40.236142852])
# sma4 array('d', [38.861097408, 39.722107172, 40.236142852])
# datetime 2019-06-18
# sma1 array('d', [39.722107172, 40.236142852, 40.28754642])
# sma2 array('d', [39.722107172, 40.236142852, 40.28754642])
# sma3 array('d', [39.722107172, 40.236142852, 40.28754642])
# sma4 array('d', [39.722107172, 40.236142852, 40.28754642])
# datetime 2019-06-19
# sma1 array('d', [40.236142852, 40.28754642, 40.338949988])
# sma2 array('d', [40.236142852, 40.28754642, 40.338949988])
# sma3 array('d', [40.236142852, 40.28754642, 40.338949988])
# sma4 array('d', [40.236142852, 40.28754642, 40.338949988])
# datetime 2019-06-20
# sma1 array('d', [40.28754642, 40.338949988, 40.60881872])
# sma2 array('d', [40.28754642, 40.338949988, 40.60881872])
# sma3 array('d', [40.28754642, 40.338949988, 40.60881872])
# sma4 array('d', [40.28754642, 40.338949988, 40.60881872])
# datetime 2019-06-21
# sma1 array('d', [40.338949988, 40.60881872, 40.660222288])
# sma2 array('d', [40.338949988, 40.60881872, 40.660222288])
# sma3 array('d', [40.338949988, 40.60881872, 40.660222288])
# sma4 array('d', [40.338949988, 40.60881872, 40.660222288])
# datetime 2019-06-24
# sma1 array('d', [40.60881872, 40.660222288, 40.840134776])
# sma2 array('d', [40.60881872, 40.660222288, 40.840134776])
# sma3 array('d', [40.60881872, 40.660222288, 40.840134776])
# sma4 array('d', [40.60881872, 40.660222288, 40.840134776])
# datetime 2019-06-25
# sma1 array('d', [40.660222288, 40.840134776, 40.917240128])
# sma2 array('d', [40.660222288, 40.840134776, 40.917240128])
# sma3 array('d', [40.660222288, 40.840134776, 40.917240128])
# sma4 array('d', [40.660222288, 40.840134776, 40.917240128])
# datetime 2019-06-26
# sma1 array('d', [40.840134776, 40.917240128, 40.99434548000001])
# sma2 array('d', [40.840134776, 40.917240128, 40.99434548000001])
# sma3 array('d', [40.840134776, 40.917240128, 40.99434548000001])
# sma4 array('d', [40.840134776, 40.917240128, 40.99434548000001])
# datetime 2019-06-27
# sma1 array('d', [40.917240128, 40.99434548000001, 40.955792804])
# sma2 array('d', [40.917240128, 40.99434548000001, 40.955792804])
# sma3 array('d', [40.917240128, 40.99434548000001, 40.955792804])
# sma4 array('d', [40.917240128, 40.99434548000001, 40.955792804])
# datetime 2019-06-28
# sma1 array('d', [40.99434548000001, 40.955792804, 40.711625856])
# sma2 array('d', [40.99434548000001, 40.955792804, 40.711625856])
# sma3 array('d', [40.99434548000001, 40.955792804, 40.711625856])
# sma4 array('d', [40.99434548000001, 40.955792804, 40.711625856])
# datetime 2019-07-01
# sma1 array('d', [40.955792804, 40.711625856, 40.570266044])
# sma2 array('d', [40.955792804, 40.711625856, 40.570266044])
# sma3 array('d', [40.955792804, 40.711625856, 40.570266044])
# sma4 array('d', [40.955792804, 40.711625856, 40.570266044])
# datetime 2019-07-02
# sma1 array('d', [40.711625856, 40.570266044, 40.506011584])
# sma2 array('d', [40.711625856, 40.570266044, 40.506011584])
# sma3 array('d', [40.711625856, 40.570266044, 40.506011584])
# sma4 array('d', [40.711625856, 40.570266044, 40.506011584])
# datetime 2019-07-03
# sma1 array('d', [40.570266044, 40.506011584, 40.660222288])
# sma2 array('d', [40.570266044, 40.506011584, 40.660222288])
# sma3 array('d', [40.570266044, 40.506011584, 40.660222288])
# sma4 array('d', [40.570266044, 40.506011584, 40.660222288])
# datetime 2019-07-04
# sma1 array('d', [40.506011584, 40.660222288, 40.891538344])
# sma2 array('d', [40.506011584, 40.660222288, 40.891538344])
# sma3 array('d', [40.506011584, 40.660222288, 40.891538344])
# sma4 array('d', [40.506011584, 40.660222288, 40.891538344])
# datetime 2019-07-05
# sma1 array('d', [40.660222288, 40.891538344, 41.1228544])
# sma2 array('d', [40.660222288, 40.891538344, 41.1228544])
# sma3 array('d', [40.660222288, 40.891538344, 41.1228544])
# sma4 array('d', [40.660222288, 40.891538344, 41.1228544])
# datetime 2019-07-08
# sma1 array('d', [40.891538344, 41.1228544, 40.891538344])
# sma2 array('d', [40.891538344, 41.1228544, 40.891538344])
# sma3 array('d', [40.891538344, 41.1228544, 40.891538344])
# sma4 array('d', [40.891538344, 41.1228544, 40.891538344])
# datetime 2019-07-09
# sma1 array('d', [41.1228544, 40.891538344, 40.737327640000004])
# sma2 array('d', [41.1228544, 40.891538344, 40.737327640000004])
# sma3 array('d', [41.1228544, 40.891538344, 40.737327640000004])
# sma4 array('d', [41.1228544, 40.891538344, 40.737327640000004])
# datetime 2019-07-10
# sma1 array('d', [40.891538344, 40.737327640000004, 40.004826795999996])
# sma2 array('d', [40.891538344, 40.737327640000004, 40.004826795999996])
# sma3 array('d', [40.891538344, 40.737327640000004, 40.004826795999996])
# sma4 array('d', [40.891538344, 40.737327640000004, 40.004826795999996])
# datetime 2019-07-11
# sma1 array('d', [40.737327640000004, 40.004826795999996, 39.490791116000004])
# sma2 array('d', [40.737327640000004, 40.004826795999996, 39.490791116000004])
# sma3 array('d', [40.737327640000004, 40.004826795999996, 39.490791116000004])
# sma4 array('d', [40.737327640000004, 40.004826795999996, 39.490791116000004])
# datetime 2019-07-12
# sma1 array('d', [40.004826795999996, 39.490791116000004, 39.143817032])
# sma2 array('d', [40.004826795999996, 39.490791116000004, 39.143817032])
# sma3 array('d', [40.004826795999996, 39.490791116000004, 39.143817032])
# sma4 array('d', [40.004826795999996, 39.490791116000004, 39.143817032])
# datetime 2019-07-15
# sma1 array('d', [39.490791116000004, 39.143817032, 39.272325952])
# sma2 array('d', [39.490791116000004, 39.143817032, 39.272325952])
# sma3 array('d', [39.490791116000004, 39.143817032, 39.272325952])
# sma4 array('d', [39.490791116000004, 39.143817032, 39.272325952])
# datetime 2019-07-16
# sma1 array('d', [39.143817032, 39.272325952, 39.619300036000006])
# sma2 array('d', [39.143817032, 39.272325952, 39.619300036000006])
# sma3 array('d', [39.143817032, 39.272325952, 39.619300036000006])
# sma4 array('d', [39.143817032, 39.272325952, 39.619300036000006])
# datetime 2019-07-17
# sma1 array('d', [39.272325952, 39.619300036000006, 40.313248204000004])
# sma2 array('d', [39.272325952, 39.619300036000006, 40.313248204000004])
# sma3 array('d', [39.272325952, 39.619300036000006, 40.313248204000004])
# sma4 array('d', [39.272325952, 39.619300036000006, 40.313248204000004])
# datetime 2019-07-18
# sma1 array('d', [39.619300036000006, 40.313248204000004, 40.454608015999995])
# sma2 array('d', [39.619300036000006, 40.313248204000004, 40.454608015999995])
# sma3 array('d', [39.619300036000006, 40.313248204000004, 40.454608015999995])
# sma4 array('d', [39.619300036000006, 40.313248204000004, 40.454608015999995])
# datetime 2019-07-19
# sma1 array('d', [40.313248204000004, 40.454608015999995, 40.93009102])
# sma2 array('d', [40.313248204000004, 40.454608015999995, 40.93009102])
# sma3 array('d', [40.313248204000004, 40.454608015999995, 40.93009102])
# sma4 array('d', [40.313248204000004, 40.454608015999995, 40.93009102])
# datetime 2019-07-22
# sma1 array('d', [40.454608015999995, 40.93009102, 41.020047264000006])
# sma2 array('d', [40.454608015999995, 40.93009102, 41.020047264000006])
# sma3 array('d', [40.454608015999995, 40.93009102, 41.020047264000006])
# sma4 array('d', [40.454608015999995, 40.93009102, 41.020047264000006])
# datetime 2019-07-23
# sma1 array('d', [40.93009102, 41.020047264000006, 40.904389236])
# sma2 array('d', [40.93009102, 41.020047264000006, 40.904389236])
# sma3 array('d', [40.93009102, 41.020047264000006, 40.904389236])
# sma4 array('d', [40.93009102, 41.020047264000006, 40.904389236])
# datetime 2019-07-24
# sma1 array('d', [41.020047264000006, 40.904389236, 40.775880316])
# sma2 array('d', [41.020047264000006, 40.904389236, 40.775880316])
# sma3 array('d', [41.020047264000006, 40.904389236, 40.775880316])
# sma4 array('d', [41.020047264000006, 40.904389236, 40.775880316])
# datetime 2019-07-25
# sma1 array('d', [40.904389236, 40.775880316, 40.750178532])
# sma2 array('d', [40.904389236, 40.775880316, 40.750178532])
# sma3 array('d', [40.904389236, 40.775880316, 40.750178532])
# sma4 array('d', [40.904389236, 40.775880316, 40.750178532])
# datetime 2019-07-26
# sma1 array('d', [40.775880316, 40.750178532, 40.595967828000006])
# sma2 array('d', [40.775880316, 40.750178532, 40.595967828000006])
# sma3 array('d', [40.775880316, 40.750178532, 40.595967828000006])
# sma4 array('d', [40.775880316, 40.750178532, 40.595967828000006])
# datetime 2019-07-29
# sma1 array('d', [40.750178532, 40.595967828000006, 40.506011584])
# sma2 array('d', [40.750178532, 40.595967828000006, 40.506011584])
# sma3 array('d', [40.750178532, 40.595967828000006, 40.506011584])
# sma4 array('d', [40.750178532, 40.595967828000006, 40.506011584])
# datetime 2019-07-30
# sma1 array('d', [40.595967828000006, 40.506011584, 40.428906231999996])
# sma2 array('d', [40.595967828000006, 40.506011584, 40.428906231999996])
# sma3 array('d', [40.595967828000006, 40.506011584, 40.428906231999996])
# sma4 array('d', [40.595967828000006, 40.506011584, 40.428906231999996])
# datetime 2019-07-31
# sma1 array('d', [40.506011584, 40.428906231999996, 40.171888392])
# sma2 array('d', [40.506011584, 40.428906231999996, 40.171888392])
# sma3 array('d', [40.506011584, 40.428906231999996, 40.171888392])
# sma4 array('d', [40.506011584, 40.428906231999996, 40.171888392])
# datetime 2019-08-01
# sma1 array('d', [40.428906231999996, 40.171888392, 39.850616091999996])
# sma2 array('d', [40.428906231999996, 40.171888392, 39.850616091999996])
# sma3 array('d', [40.428906231999996, 40.171888392, 39.850616091999996])
# sma4 array('d', [40.428906231999996, 40.171888392, 39.850616091999996])
# datetime 2019-08-02
# sma1 array('d', [40.171888392, 39.850616091999996, 39.118115247999995])
# sma2 array('d', [40.171888392, 39.850616091999996, 39.118115247999995])
# sma3 array('d', [40.171888392, 39.850616091999996, 39.118115247999995])
# sma4 array('d', [40.171888392, 39.850616091999996, 39.118115247999995])
# datetime 2019-08-05
# sma1 array('d', [39.850616091999996, 39.118115247999995, 38.462719756])
# sma2 array('d', [39.850616091999996, 39.118115247999995, 38.462719756])
# sma3 array('d', [39.850616091999996, 39.118115247999995, 38.462719756])
# sma4 array('d', [39.850616091999996, 39.118115247999995, 38.462719756])
# datetime 2019-08-06
# sma1 array('d', [39.118115247999995, 38.462719756, 37.858727832])
# sma2 array('d', [39.118115247999995, 38.462719756, 37.858727832])
# sma3 array('d', [39.118115247999995, 38.462719756, 37.858727832])
# sma4 array('d', [39.118115247999995, 38.462719756, 37.858727832])
# datetime 2019-08-07
# sma1 array('d', [38.462719756, 37.858727832, 37.52460463999999])
# sma2 array('d', [38.462719756, 37.858727832, 37.52460463999999])
# sma3 array('d', [38.462719756, 37.858727832, 37.52460463999999])
# sma4 array('d', [38.462719756, 37.858727832, 37.52460463999999])
# datetime 2019-08-08
# sma1 array('d', [37.858727832, 37.52460463999999, 37.254735908])
# sma2 array('d', [37.858727832, 37.52460463999999, 37.254735908])
# sma3 array('d', [37.858727832, 37.52460463999999, 37.254735908])
# sma4 array('d', [37.858727832, 37.52460463999999, 37.254735908])
# datetime 2019-08-09
# sma1 array('d', [37.52460463999999, 37.254735908, 37.113376096])
# sma2 array('d', [37.52460463999999, 37.254735908, 37.113376096])
# sma3 array('d', [37.52460463999999, 37.254735908, 37.113376096])
# sma4 array('d', [37.52460463999999, 37.254735908, 37.113376096])
# datetime 2019-08-12
# sma1 array('d', [37.254735908, 37.113376096, 37.113376096])
# sma2 array('d', [37.254735908, 37.113376096, 37.113376096])
# sma3 array('d', [37.254735908, 37.113376096, 37.113376096])
# sma4 array('d', [37.254735908, 37.113376096, 37.113376096])
# datetime 2019-08-13
# sma1 array('d', [37.113376096, 37.113376096, 36.9463145])
# sma2 array('d', [37.113376096, 37.113376096, 36.9463145])
# sma3 array('d', [37.113376096, 37.113376096, 36.9463145])
# sma4 array('d', [37.113376096, 37.113376096, 36.9463145])
# datetime 2019-08-14
# sma1 array('d', [37.113376096, 36.9463145, 36.702147552])
# sma2 array('d', [37.113376096, 36.9463145, 36.702147552])
# sma3 array('d', [37.113376096, 36.9463145, 36.702147552])
# sma4 array('d', [37.113376096, 36.9463145, 36.702147552])
# datetime 2019-08-15
# sma1 array('d', [36.9463145, 36.702147552, 36.586489524])
# sma2 array('d', [36.9463145, 36.702147552, 36.586489524])
# sma3 array('d', [36.9463145, 36.702147552, 36.586489524])
# sma4 array('d', [36.9463145, 36.702147552, 36.586489524])
# datetime 2019-08-16
# sma1 array('d', [36.702147552, 36.586489524, 36.522235064])
# sma2 array('d', [36.702147552, 36.586489524, 36.522235064])
# sma3 array('d', [36.702147552, 36.586489524, 36.522235064])
# sma4 array('d', [36.702147552, 36.586489524, 36.522235064])
# datetime 2019-08-19
# sma1 array('d', [36.586489524, 36.522235064, 36.676445768])
# sma2 array('d', [36.586489524, 36.522235064, 36.676445768])
# sma3 array('d', [36.586489524, 36.522235064, 36.676445768])
# sma4 array('d', [36.586489524, 36.522235064, 36.676445768])
# datetime 2019-08-20
# sma1 array('d', [36.522235064, 36.676445768, 37.01056896])
# sma2 array('d', [36.522235064, 36.676445768, 37.01056896])
# sma3 array('d', [36.522235064, 36.676445768, 37.01056896])
# sma4 array('d', [36.522235064, 36.676445768, 37.01056896])
# datetime 2019-08-21
# sma1 array('d', [36.676445768, 37.01056896, 37.473201072])
# sma2 array('d', [36.676445768, 37.01056896, 37.473201072])
# sma3 array('d', [36.676445768, 37.01056896, 37.473201072])
# sma4 array('d', [36.676445768, 37.01056896, 37.473201072])
# datetime 2019-08-22
# sma1 array('d', [37.01056896, 37.473201072, 37.935833184])
# sma2 array('d', [37.01056896, 37.473201072, 37.935833184])
# sma3 array('d', [37.01056896, 37.473201072, 37.935833184])
# sma4 array('d', [37.01056896, 37.473201072, 37.935833184])
# datetime 2019-08-23
# sma1 array('d', [37.473201072, 37.935833184, 38.591228676])
# sma2 array('d', [37.473201072, 37.935833184, 38.591228676])
# sma3 array('d', [37.473201072, 37.935833184, 38.591228676])
# sma4 array('d', [37.473201072, 37.935833184, 38.591228676])
# datetime 2019-08-26
# sma1 array('d', [37.935833184, 38.591228676, 38.886799192])
# sma2 array('d', [37.935833184, 38.591228676, 38.886799192])
# sma3 array('d', [37.935833184, 38.591228676, 38.886799192])
# sma4 array('d', [37.935833184, 38.591228676, 38.886799192])
# datetime 2019-08-27
# sma1 array('d', [38.591228676, 38.886799192, 39.053860787999994])
# sma2 array('d', [38.591228676, 38.886799192, 39.053860787999994])
# sma3 array('d', [38.591228676, 38.886799192, 39.053860787999994])
# sma4 array('d', [38.591228676, 38.886799192, 39.053860787999994])
# datetime 2019-08-28
# sma1 array('d', [38.886799192, 39.053860787999994, 39.105264356])
# sma2 array('d', [38.886799192, 39.053860787999994, 39.105264356])
# sma3 array('d', [38.886799192, 39.053860787999994, 39.105264356])
# sma4 array('d', [38.886799192, 39.053860787999994, 39.105264356])
# datetime 2019-08-29
# sma1 array('d', [39.053860787999994, 39.105264356, 38.886799192])
# sma2 array('d', [39.053860787999994, 39.105264356, 38.886799192])
# sma3 array('d', [39.053860787999994, 39.105264356, 38.886799192])
# sma4 array('d', [39.053860787999994, 39.105264356, 38.886799192])
# datetime 2019-08-30
# sma1 array('d', [39.105264356, 38.886799192, 38.308509052])
# sma2 array('d', [39.105264356, 38.886799192, 38.308509052])
# sma3 array('d', [39.105264356, 38.886799192, 38.308509052])
# sma4 array('d', [39.105264356, 38.886799192, 38.308509052])
# datetime 2019-09-02
# sma1 array('d', [38.886799192, 38.308509052, 37.922982292])
# sma2 array('d', [38.886799192, 38.308509052, 37.922982292])
# sma3 array('d', [38.886799192, 38.308509052, 37.922982292])
# sma4 array('d', [38.886799192, 38.308509052, 37.922982292])
# datetime 2019-09-03
# sma1 array('d', [38.308509052, 37.922982292, 37.563157316])
# sma2 array('d', [38.308509052, 37.922982292, 37.563157316])
# sma3 array('d', [38.308509052, 37.922982292, 37.563157316])
# sma4 array('d', [38.308509052, 37.922982292, 37.563157316])
# datetime 2019-09-04
# sma1 array('d', [37.922982292, 37.563157316, 37.46035018])
# sma2 array('d', [37.922982292, 37.563157316, 37.46035018])
# sma3 array('d', [37.922982292, 37.563157316, 37.46035018])
# sma4 array('d', [37.922982292, 37.563157316, 37.46035018])
# datetime 2019-09-05
# sma1 array('d', [37.563157316, 37.46035018, 37.653113559999994])
# sma2 array('d', [37.563157316, 37.46035018, 37.653113559999994])
# sma3 array('d', [37.563157316, 37.46035018, 37.653113559999994])
# sma4 array('d', [37.563157316, 37.46035018, 37.653113559999994])
# datetime 2019-09-06
# sma1 array('d', [37.46035018, 37.653113559999994, 38.128596564])
# sma2 array('d', [37.46035018, 37.653113559999994, 38.128596564])
# sma3 array('d', [37.46035018, 37.653113559999994, 38.128596564])
# sma4 array('d', [37.46035018, 37.653113559999994, 38.128596564])
# datetime 2019-09-09
# sma1 array('d', [37.653113559999994, 38.128596564, 38.591228676])
# sma2 array('d', [37.653113559999994, 38.128596564, 38.591228676])
# sma3 array('d', [37.653113559999994, 38.128596564, 38.591228676])
# sma4 array('d', [37.653113559999994, 38.128596564, 38.591228676])
# datetime 2019-09-10
# sma1 array('d', [38.128596564, 38.591228676, 38.989606327999994])
# sma2 array('d', [38.128596564, 38.591228676, 38.989606327999994])
# sma3 array('d', [38.128596564, 38.591228676, 38.989606327999994])
# sma4 array('d', [38.128596564, 38.591228676, 38.989606327999994])
# datetime 2019-09-11
# sma1 array('d', [38.591228676, 38.989606327999994, 39.079562572])
# sma2 array('d', [38.591228676, 38.989606327999994, 39.079562572])
# sma3 array('d', [38.591228676, 38.989606327999994, 39.079562572])
# sma4 array('d', [38.591228676, 38.989606327999994, 39.079562572])
# datetime 2019-09-12
# sma1 array('d', [38.989606327999994, 39.079562572, 39.477940223999994])
# sma2 array('d', [38.989606327999994, 39.079562572, 39.477940223999994])
# sma3 array('d', [38.989606327999994, 39.079562572, 39.477940223999994])
# sma4 array('d', [38.989606327999994, 39.079562572, 39.477940223999994])
# datetime 2019-09-16
# sma1 array('d', [39.079562572, 39.477940223999994, 39.786361632])
# sma2 array('d', [39.079562572, 39.477940223999994, 39.786361632])
# sma3 array('d', [39.079562572, 39.477940223999994, 39.786361632])
# sma4 array('d', [39.079562572, 39.477940223999994, 39.786361632])
# datetime 2019-09-17
# sma1 array('d', [39.477940223999994, 39.786361632, 39.876317876])
# sma2 array('d', [39.477940223999994, 39.786361632, 39.876317876])
# sma3 array('d', [39.477940223999994, 39.786361632, 39.876317876])
# sma4 array('d', [39.477940223999994, 39.786361632, 39.876317876])
# datetime 2019-09-18
# sma1 array('d', [39.786361632, 39.876317876, 40.274695528])
# sma2 array('d', [39.786361632, 39.876317876, 40.274695528])
# sma3 array('d', [39.786361632, 39.876317876, 40.274695528])
# sma4 array('d', [39.786361632, 39.876317876, 40.274695528])
# datetime 2019-09-19
# sma1 array('d', [39.876317876, 40.274695528, 40.595967828])
# sma2 array('d', [39.876317876, 40.274695528, 40.595967828])
# sma3 array('d', [39.876317876, 40.274695528, 40.595967828])
# sma4 array('d', [39.876317876, 40.274695528, 40.595967828])
# datetime 2019-09-20
# sma1 array('d', [40.274695528, 40.595967828, 40.531713368])
# sma2 array('d', [40.274695528, 40.595967828, 40.531713368])
# sma3 array('d', [40.274695528, 40.595967828, 40.531713368])
# sma4 array('d', [40.274695528, 40.595967828, 40.531713368])
# datetime 2019-09-23
# sma1 array('d', [40.595967828, 40.531713368, 40.338949988])
# sma2 array('d', [40.595967828, 40.531713368, 40.338949988])
# sma3 array('d', [40.595967828, 40.531713368, 40.338949988])
# sma4 array('d', [40.595967828, 40.531713368, 40.338949988])
# ...
# sma2 array('d', [33.769562424, 33.95859636, 34.107123023999996])
# sma3 array('d', [33.769562424, 33.95859636, 34.107123023999996])
# sma4 array('d', [33.769562424, 33.95859636, 34.107123023999996])
# datetime 2020-11-10
# sma1 array('d', [33.95859636, 34.107123023999996, 34.120625448])
# sma2 array('d', [33.95859636, 34.107123023999996, 34.120625448])
# sma3 array('d', [33.95859636, 34.107123023999996, 34.120625448])
# sma4 array('d', [33.95859636, 34.107123023999996, 34.120625448])
# datetime 2020-11-11
# sma1 array('d', [34.107123023999996, 34.120625448, 34.36366908])
# sma2 array('d', [34.107123023999996, 34.120625448, 34.36366908])
# sma3 array('d', [34.107123023999996, 34.120625448, 34.36366908])
# sma4 array('d', [34.107123023999996, 34.120625448, 34.36366908])
# datetime 2020-11-12
# sma1 array('d', [34.120625448, 34.36366908, 34.417678776])
# sma2 array('d', [34.120625448, 34.36366908, 34.417678776])
# sma3 array('d', [34.120625448, 34.36366908, 34.417678776])
# sma4 array('d', [34.120625448, 34.36366908, 34.417678776])
# datetime 2020-11-13
# sma1 array('d', [34.36366908, 34.417678776, 34.282654536])
# sma2 array('d', [34.36366908, 34.417678776, 34.282654536])
# sma3 array('d', [34.36366908, 34.417678776, 34.282654536])
# sma4 array('d', [34.36366908, 34.417678776, 34.282654536])
# datetime 2020-11-16
# sma1 array('d', [34.417678776, 34.282654536, 34.188137568])
# sma2 array('d', [34.417678776, 34.282654536, 34.188137568])
# sma3 array('d', [34.417678776, 34.282654536, 34.188137568])
# sma4 array('d', [34.417678776, 34.282654536, 34.188137568])
# datetime 2020-11-17
# sma1 array('d', [34.282654536, 34.188137568, 34.377171504])
# sma2 array('d', [34.282654536, 34.188137568, 34.377171504])
# sma3 array('d', [34.282654536, 34.188137568, 34.377171504])
# sma4 array('d', [34.282654536, 34.188137568, 34.377171504])
# datetime 2020-11-18
# sma1 array('d', [34.188137568, 34.377171504, 34.417678776])
# sma2 array('d', [34.188137568, 34.377171504, 34.417678776])
# sma3 array('d', [34.188137568, 34.377171504, 34.417678776])
# sma4 array('d', [34.188137568, 34.377171504, 34.417678776])
# datetime 2020-11-19
# sma1 array('d', [34.377171504, 34.417678776, 34.49869332])
# sma2 array('d', [34.377171504, 34.417678776, 34.49869332])
# sma3 array('d', [34.377171504, 34.417678776, 34.49869332])
# sma4 array('d', [34.377171504, 34.417678776, 34.49869332])
# datetime 2020-11-20
# sma1 array('d', [34.417678776, 34.49869332, 34.741736952])
# sma2 array('d', [34.417678776, 34.49869332, 34.741736952])
# sma3 array('d', [34.417678776, 34.49869332, 34.741736952])
# sma4 array('d', [34.417678776, 34.49869332, 34.741736952])
# datetime 2020-11-23
# sma1 array('d', [34.49869332, 34.741736952, 34.930770888])
# sma2 array('d', [34.49869332, 34.741736952, 34.930770888])
# sma3 array('d', [34.49869332, 34.741736952, 34.930770888])
# sma4 array('d', [34.49869332, 34.741736952, 34.930770888])
# datetime 2020-11-24
# sma1 array('d', [34.741736952, 34.930770888, 34.849756344])
# sma2 array('d', [34.741736952, 34.930770888, 34.849756344])
# sma3 array('d', [34.741736952, 34.930770888, 34.849756344])
# sma4 array('d', [34.741736952, 34.930770888, 34.849756344])
# datetime 2020-11-25
# sma1 array('d', [34.930770888, 34.849756344, 34.795746648])
# sma2 array('d', [34.930770888, 34.849756344, 34.795746648])
# sma3 array('d', [34.930770888, 34.849756344, 34.795746648])
# sma4 array('d', [34.930770888, 34.849756344, 34.795746648])
# datetime 2020-11-26
# sma1 array('d', [34.849756344, 34.795746648, 34.7687418])
# sma2 array('d', [34.849756344, 34.795746648, 34.7687418])
# sma3 array('d', [34.849756344, 34.795746648, 34.7687418])
# sma4 array('d', [34.849756344, 34.795746648, 34.7687418])
# datetime 2020-11-27
# sma1 array('d', [34.795746648, 34.7687418, 34.836253920000004])
# sma2 array('d', [34.795746648, 34.7687418, 34.836253920000004])
# sma3 array('d', [34.795746648, 34.7687418, 34.836253920000004])
# sma4 array('d', [34.795746648, 34.7687418, 34.836253920000004])
# datetime 2020-11-30
# sma1 array('d', [34.7687418, 34.836253920000004, 34.795746648])
# sma2 array('d', [34.7687418, 34.836253920000004, 34.795746648])
# sma3 array('d', [34.7687418, 34.836253920000004, 34.795746648])
# sma4 array('d', [34.7687418, 34.836253920000004, 34.795746648])
# datetime 2020-12-01
# sma1 array('d', [34.836253920000004, 34.795746648, 34.876761192])
# sma2 array('d', [34.836253920000004, 34.795746648, 34.876761192])
# sma3 array('d', [34.836253920000004, 34.795746648, 34.876761192])
# sma4 array('d', [34.836253920000004, 34.795746648, 34.876761192])
# datetime 2020-12-02
# sma1 array('d', [34.795746648, 34.876761192, 34.94427331199999])
# sma2 array('d', [34.795746648, 34.876761192, 34.94427331199999])
# sma3 array('d', [34.795746648, 34.876761192, 34.94427331199999])
# sma4 array('d', [34.795746648, 34.876761192, 34.94427331199999])
# datetime 2020-12-03
# sma1 array('d', [34.876761192, 34.94427331199999, 34.957775735999995])
# sma2 array('d', [34.876761192, 34.94427331199999, 34.957775735999995])
# sma3 array('d', [34.876761192, 34.94427331199999, 34.957775735999995])
# sma4 array('d', [34.876761192, 34.94427331199999, 34.957775735999995])
# datetime 2020-12-04
# sma1 array('d', [34.94427331199999, 34.957775735999995, 34.809249072])
# sma2 array('d', [34.94427331199999, 34.957775735999995, 34.809249072])
# sma3 array('d', [34.94427331199999, 34.957775735999995, 34.809249072])
# sma4 array('d', [34.94427331199999, 34.957775735999995, 34.809249072])
# datetime 2020-12-07
# sma1 array('d', [34.957775735999995, 34.809249072, 34.620215136])
# sma2 array('d', [34.957775735999995, 34.809249072, 34.620215136])
# sma3 array('d', [34.957775735999995, 34.809249072, 34.620215136])
# sma4 array('d', [34.957775735999995, 34.809249072, 34.620215136])
# datetime 2020-12-08
# sma1 array('d', [34.809249072, 34.620215136, 34.377171504])
# sma2 array('d', [34.809249072, 34.620215136, 34.377171504])
# sma3 array('d', [34.809249072, 34.620215136, 34.377171504])
# sma4 array('d', [34.809249072, 34.620215136, 34.377171504])
# datetime 2020-12-09
# sma1 array('d', [34.620215136, 34.377171504, 34.080118176])
# sma2 array('d', [34.620215136, 34.377171504, 34.080118176])
# sma3 array('d', [34.620215136, 34.377171504, 34.080118176])
# sma4 array('d', [34.620215136, 34.377171504, 34.080118176])
# datetime 2020-12-10
# sma1 array('d', [34.377171504, 34.080118176, 33.850576968])
# sma2 array('d', [34.377171504, 34.080118176, 33.850576968])
# sma3 array('d', [34.377171504, 34.080118176, 33.850576968])
# sma4 array('d', [34.377171504, 34.080118176, 33.850576968])
# datetime 2020-12-11
# sma1 array('d', [34.080118176, 33.850576968, 33.607533336])
# sma2 array('d', [34.080118176, 33.850576968, 33.607533336])
# sma3 array('d', [34.080118176, 33.850576968, 33.607533336])
# sma4 array('d', [34.080118176, 33.850576968, 33.607533336])
# datetime 2020-12-14
# sma1 array('d', [33.850576968, 33.607533336, 33.513016368])
# sma2 array('d', [33.850576968, 33.607533336, 33.513016368])
# sma3 array('d', [33.850576968, 33.607533336, 33.513016368])
# sma4 array('d', [33.850576968, 33.607533336, 33.513016368])
# datetime 2020-12-15
# sma1 array('d', [33.607533336, 33.513016368, 33.377992128])
# sma2 array('d', [33.607533336, 33.513016368, 33.377992128])
# sma3 array('d', [33.607533336, 33.513016368, 33.377992128])
# sma4 array('d', [33.607533336, 33.513016368, 33.377992128])
# datetime 2020-12-16
# sma1 array('d', [33.513016368, 33.377992128, 33.242967887999995])
# sma2 array('d', [33.513016368, 33.377992128, 33.242967887999995])
# sma3 array('d', [33.513016368, 33.377992128, 33.242967887999995])
# sma4 array('d', [33.513016368, 33.377992128, 33.242967887999995])
# datetime 2020-12-17
# sma1 array('d', [33.377992128, 33.242967887999995, 33.121446072000005])
# sma2 array('d', [33.377992128, 33.242967887999995, 33.121446072000005])
# sma3 array('d', [33.377992128, 33.242967887999995, 33.121446072000005])
# sma4 array('d', [33.377992128, 33.242967887999995, 33.121446072000005])
# datetime 2020-12-18
# sma1 array('d', [33.242967887999995, 33.121446072000005, 32.999924256])
# sma2 array('d', [33.242967887999995, 33.121446072000005, 32.999924256])
# sma3 array('d', [33.242967887999995, 33.121446072000005, 32.999924256])
# sma4 array('d', [33.242967887999995, 33.121446072000005, 32.999924256])
# datetime 2020-12-21
# sma1 array('d', [33.121446072000005, 32.999924256, 32.824392744])
# sma2 array('d', [33.121446072000005, 32.999924256, 32.824392744])
# sma3 array('d', [33.121446072000005, 32.999924256, 32.824392744])
# sma4 array('d', [33.121446072000005, 32.999924256, 32.824392744])
# datetime 2020-12-22
# sma1 array('d', [32.999924256, 32.824392744, 32.60835396])
# sma2 array('d', [32.999924256, 32.824392744, 32.60835396])
# sma3 array('d', [32.999924256, 32.824392744, 32.60835396])
# sma4 array('d', [32.999924256, 32.824392744, 32.60835396])
# datetime 2020-12-23
# sma1 array('d', [32.824392744, 32.60835396, 32.419320024])
# sma2 array('d', [32.824392744, 32.60835396, 32.419320024])
# sma3 array('d', [32.824392744, 32.60835396, 32.419320024])
# sma4 array('d', [32.824392744, 32.60835396, 32.419320024])
# datetime 2020-12-24
# sma1 array('d', [32.60835396, 32.419320024, 32.068257])
# sma2 array('d', [32.60835396, 32.419320024, 32.068257])
# sma3 array('d', [32.60835396, 32.419320024, 32.068257])
# sma4 array('d', [32.60835396, 32.419320024, 32.068257])
# datetime 2020-12-25
# sma1 array('d', [32.419320024, 32.068257, 31.811710943999998])
# sma2 array('d', [32.419320024, 32.068257, 31.811710943999998])
# sma3 array('d', [32.419320024, 32.068257, 31.811710943999998])
# sma4 array('d', [32.419320024, 32.068257, 31.811710943999998])
# datetime 2020-12-28
# sma1 array('d', [32.068257, 31.811710943999998, 31.52816004])
# sma2 array('d', [32.068257, 31.811710943999998, 31.52816004])
# sma3 array('d', [32.068257, 31.811710943999998, 31.52816004])
# sma4 array('d', [32.068257, 31.811710943999998, 31.52816004])
# datetime 2020-12-29
# sma1 array('d', [31.811710943999998, 31.52816004, 31.420140648])
# sma2 array('d', [31.811710943999998, 31.52816004, 31.420140648])
# sma3 array('d', [31.811710943999998, 31.52816004, 31.420140648])
# sma4 array('d', [31.811710943999998, 31.52816004, 31.420140648])
# datetime 2020-12-30
# sma1 array('d', [31.52816004, 31.420140648, 31.339126104])
# sma2 array('d', [31.52816004, 31.420140648, 31.339126104])
# sma3 array('d', [31.52816004, 31.420140648, 31.339126104])
# sma4 array('d', [31.52816004, 31.420140648, 31.339126104])
# datetime 2020-12-31
# sma1 array('d', [31.420140648, 31.339126104, 31.352628528000004])
# sma2 array('d', [31.420140648, 31.339126104, 31.352628528000004])
# sma3 array('d', [31.420140648, 31.339126104, 31.352628528000004])
# sma4 array('d', [31.420140648, 31.339126104, 31.352628528000004])
# datetime 2021-01-04
# sma1 array('d', [31.339126104, 31.352628528000004, 31.109584896])
# sma2 array('d', [31.339126104, 31.352628528000004, 31.109584896])
# sma3 array('d', [31.339126104, 31.352628528000004, 31.109584896])
# sma4 array('d', [31.339126104, 31.352628528000004, 31.109584896])
# datetime 2021-01-05
# sma1 array('d', [31.352628528000004, 31.109584896, 30.907048536])
# sma2 array('d', [31.352628528000004, 31.109584896, 30.907048536])
# sma3 array('d', [31.352628528000004, 31.109584896, 30.907048536])
# sma4 array('d', [31.352628528000004, 31.109584896, 30.907048536])
# datetime 2021-01-06
# sma1 array('d', [31.109584896, 30.907048536, 30.596492784])
# sma2 array('d', [31.109584896, 30.907048536, 30.596492784])
# sma3 array('d', [31.109584896, 30.907048536, 30.596492784])
# sma4 array('d', [31.109584896, 30.907048536, 30.596492784])
# datetime 2021-01-07
# sma1 array('d', [30.907048536, 30.596492784, 30.258932184000003])
# sma2 array('d', [30.907048536, 30.596492784, 30.258932184000003])
# sma3 array('d', [30.907048536, 30.596492784, 30.258932184000003])
# sma4 array('d', [30.907048536, 30.596492784, 30.258932184000003])
# datetime 2021-01-08
# sma1 array('d', [30.596492784, 30.258932184000003, 30.002386128])
# sma2 array('d', [30.596492784, 30.258932184000003, 30.002386128])
# sma3 array('d', [30.596492784, 30.258932184000003, 30.002386128])
# sma4 array('d', [30.596492784, 30.258932184000003, 30.002386128])
# datetime 2021-01-11
# sma1 array('d', [30.258932184000003, 30.002386128, 29.921371584000003])
# sma2 array('d', [30.258932184000003, 30.002386128, 29.921371584000003])
# sma3 array('d', [30.258932184000003, 30.002386128, 29.921371584000003])
# sma4 array('d', [30.258932184000003, 30.002386128, 29.921371584000003])
# datetime 2021-01-12
# sma1 array('d', [30.002386128, 29.921371584000003, 29.826854616000002])
# sma2 array('d', [30.002386128, 29.921371584000003, 29.826854616000002])
# sma3 array('d', [30.002386128, 29.921371584000003, 29.826854616000002])
# sma4 array('d', [30.002386128, 29.921371584000003, 29.826854616000002])
# datetime 2021-01-13
# sma1 array('d', [29.921371584000003, 29.826854616000002, 29.799849768])
# sma2 array('d', [29.921371584000003, 29.826854616000002, 29.799849768])
# sma3 array('d', [29.921371584000003, 29.826854616000002, 29.799849768])
# sma4 array('d', [29.921371584000003, 29.826854616000002, 29.799849768])
# datetime 2021-01-14
# sma1 array('d', [29.826854616000002, 29.799849768, 29.921371584000003])
# sma2 array('d', [29.826854616000002, 29.799849768, 29.921371584000003])
# sma3 array('d', [29.826854616000002, 29.799849768, 29.921371584000003])
# sma4 array('d', [29.826854616000002, 29.799849768, 29.921371584000003])
# datetime 2021-01-15
# sma1 array('d', [29.799849768, 29.921371584000003, 30.015888552])
# sma2 array('d', [29.799849768, 29.921371584000003, 30.015888552])
# sma3 array('d', [29.799849768, 29.921371584000003, 30.015888552])
# sma4 array('d', [29.799849768, 29.921371584000003, 30.015888552])
# datetime 2021-01-18
# sma1 array('d', [29.921371584000003, 30.015888552, 30.177917639999997])
# sma2 array('d', [29.921371584000003, 30.015888552, 30.177917639999997])
# sma3 array('d', [29.921371584000003, 30.015888552, 30.177917639999997])
# sma4 array('d', [29.921371584000003, 30.015888552, 30.177917639999997])
# datetime 2021-01-19
# sma1 array('d', [30.015888552, 30.177917639999997, 30.474970968])
# sma2 array('d', [30.015888552, 30.177917639999997, 30.474970968])
# sma3 array('d', [30.015888552, 30.177917639999997, 30.474970968])
# sma4 array('d', [30.015888552, 30.177917639999997, 30.474970968])
# datetime 2021-01-20
# sma1 array('d', [30.177917639999997, 30.474970968, 30.609995207999997])
# sma2 array('d', [30.177917639999997, 30.474970968, 30.609995207999997])
# sma3 array('d', [30.177917639999997, 30.474970968, 30.609995207999997])
# sma4 array('d', [30.177917639999997, 30.474970968, 30.609995207999997])
# datetime 2021-01-21
# sma1 array('d', [30.474970968, 30.609995207999997, 30.582990360000004])
# sma2 array('d', [30.474970968, 30.609995207999997, 30.582990360000004])
# sma3 array('d', [30.474970968, 30.609995207999997, 30.582990360000004])
# sma4 array('d', [30.474970968, 30.609995207999997, 30.582990360000004])
# datetime 2021-01-22
# sma1 array('d', [30.609995207999997, 30.582990360000004, 30.44796612])
# sma2 array('d', [30.609995207999997, 30.582990360000004, 30.44796612])
# sma3 array('d', [30.609995207999997, 30.582990360000004, 30.44796612])
# sma4 array('d', [30.609995207999997, 30.582990360000004, 30.44796612])
# datetime 2021-01-25
# sma1 array('d', [30.582990360000004, 30.44796612, 30.150912792000003])
# sma2 array('d', [30.582990360000004, 30.44796612, 30.150912792000003])
# sma3 array('d', [30.582990360000004, 30.44796612, 30.150912792000003])
# sma4 array('d', [30.582990360000004, 30.44796612, 30.150912792000003])
# datetime 2021-01-26
# sma1 array('d', [30.44796612, 30.150912792000003, 29.678327952])
# sma2 array('d', [30.44796612, 30.150912792000003, 29.678327952])
# sma3 array('d', [30.44796612, 30.150912792000003, 29.678327952])
# sma4 array('d', [30.44796612, 30.150912792000003, 29.678327952])
# datetime 2021-01-27
# sma1 array('d', [30.150912792000003, 29.678327952, 29.340767352])
# sma2 array('d', [30.150912792000003, 29.678327952, 29.340767352])
# sma3 array('d', [30.150912792000003, 29.678327952, 29.340767352])
# sma4 array('d', [30.150912792000003, 29.678327952, 29.340767352])
# datetime 2021-01-28
# sma1 array('d', [29.678327952, 29.340767352, 29.0302116])
# sma2 array('d', [29.678327952, 29.340767352, 29.0302116])
# sma3 array('d', [29.678327952, 29.340767352, 29.0302116])
# sma4 array('d', [29.678327952, 29.340767352, 29.0302116])

# %% [markdown]
# # 三、调用指标时的各种简写形式

# %%
class TestStrategy(bt.Strategy):
    
    def __init__(self):
        self.sma5 = btind.SimpleMovingAverage(period=5) # 5日均线
        self.sma10 = btind.SimpleMovingAverage(period=10) # 10日均线
        self.buy_sig = self.sma5 > self.sma10 # 5日均线上穿10日均线
      
    def next(self):
        # 提取当前时间点
        print('datetime', self.datas[0].datetime.date(0))
        # 打印当前值
        print('close', self.data.close[0], self.data.close)
        print('sma5', self.sma5[0], self.sma5)
        print('sma10', self.sma10[0], self.sma10)
        print('buy_sig', self.buy_sig[0], self.buy_sig)
        # 比较收盘价与均线的大小
        if self.data.close > self.sma5:
            print('------收盘价上穿5日均线------')
        if self.data.close[0] > self.sma10:
            print('------收盘价上穿10日均线------')
        if self.buy_sig:
            print('------ buy ------')
        
cerebro2 = bt.Cerebro()
st_date = datetime.datetime(2019,1,2)
end_date = datetime.datetime(2021,1,28)
datafeed1 = bt.feeds.PandasData(dataname=data1, fromdate=st_date, todate=end_date)
cerebro2.adddata(datafeed1, name='600466.SH')       
cerebro2.addstrategy(TestStrategy)
rasult = cerebro2.run()
# Out:
# datetime 2019-01-15
# close 33.06489128 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 33.18826774 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 33.101904218 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2019-01-16
# close 32.63307367 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 32.966190112 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 33.12657951 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-01-17
# close 32.0778796 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 32.682424254 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 33.151254802 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-01-18
# close 32.75645013 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 32.608398378 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 33.077228926 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# datetime 2019-01-21
# close 32.44800898 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 32.596060732 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 32.960021289 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-01-22
# close 32.44800898 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 32.472684271999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 32.830476006 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-01-23
# close 32.50969721 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 32.44800898 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 32.707099546 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# datetime 2019-01-24
# close 32.38632075 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 32.50969721 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 32.596060732 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-01-25
# close 33.06489128 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 32.57138544 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 32.589891909 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# datetime 2019-01-28
# close 33.86683827 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 32.855151297999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 32.725606015 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-01-29
# close 34.79216172 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 33.323981846 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 32.898333058999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-01-30
# close 34.23696765 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 33.669435934 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 33.058722457 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-01-31
# close 34.23696765 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 34.039565314 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 33.274631262 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-02-01
# close 34.73047349 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 34.372681756 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 33.472033598 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-02-11
# close 35.71748517 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 34.742811136 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 33.798981217 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-02-12
# close 35.65579694 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 34.91553818 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 34.119760013000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-02-13
# close 36.3960557 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 35.34735579 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 34.508395862 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-02-14
# close 36.14930278 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 35.729822816 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 34.884694065000005 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-02-15
# close 34.91553818 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 35.766835754 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 35.069758754999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2019-02-18
# close 35.90254986 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 35.803848691999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 35.273329914 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-02-19
# close 35.10060287 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 35.692809878000006 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 35.304174029 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2019-02-20
# close 35.40904402 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 35.495407541999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 35.421381666 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2019-02-21
# close 34.85384995 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 35.236316976 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 35.483069896 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-02-22
# close 35.1622911 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 35.28566756 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 35.526251657 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-02-25
# close 37.012938 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 35.507745188 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 35.65579694 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# datetime 2019-02-26
# close 37.75319676 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 36.038263966 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 35.865536922000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-02-27
# close 38.49345552 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 36.655146265999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 36.075276904 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-02-28
# close 38.30839083 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 37.346054442 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 36.291185709000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-01
# close 38.61683198 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 38.036962618000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 36.661315089 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-04
# close 39.17202605 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 38.468780228 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 36.988262708 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-05
# close 41.88630817 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 39.295402509999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 37.666833237999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-06
# close 42.25643755 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.047998916 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 38.351572591 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-07
# close 41.45449056 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.677218862000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 39.011636652 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-08
# close 38.55514375 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.664881216000005 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 39.350921917 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2019-03-11
# close 39.23371428 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.677218862000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 39.572999545 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2019-03-12
# close 40.52916711 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.40579065 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 39.85059658 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-13
# close 42.31812578 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.418128296000006 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.233063606 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-14
# close 41.20773764 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.368777712 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.522998287 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# datetime 2019-03-15
# close 42.62656693 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 41.183062348 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.923971782 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-18
# close 44.47721383 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 42.231762258 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 41.454490559999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-19
# close 44.60059029 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 43.046046894 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 41.725918772 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-20
# close 44.72396675 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 43.527215088000005 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 41.972671692 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-21
# close 46.14279604 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 44.514226768 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 42.44150224 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-22
# close 45.71097843 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 45.131109068 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 43.157085708 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-25
# close 45.6492902 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 45.365524342 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 43.7986433 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-26
# close 44.47721383 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 45.340849049999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 44.193447972 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-27
# close 45.58760197 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 45.513576094 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 44.520395590999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-03-28
# close 43.49020215 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 44.983057316 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 44.748642042 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2019-03-29
# close 45.52591374 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 44.946044377999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 45.038576723 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# datetime 2019-04-01
# close 47.74669002 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 45.365524342 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 45.365524342 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# datetime 2019-04-02
# close 47.43824887 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 45.95773135 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 45.6492902 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-04-03
# close 48.17850763 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 46.475912482 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 45.994744288 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-04-04
# close 48.1168194 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 47.401235932 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 46.192146623999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-04-08
# close 47.4999371 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 47.796040604 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 46.371042491000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-04-09
# close 52.18824258 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 48.684351116 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 47.024937729 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-04-10
# close 50.46097214 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 49.288895769999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 47.62331356 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-04-11
# close 48.7337017 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 49.399934584 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 47.937923533 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-04-12
# close 48.54863701 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 49.486298106 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 48.443767019 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-04-15
# close 47.99344294 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 49.584999274 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 48.690519939 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2019-04-16
# close 46.63630188 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 48.474611134 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 48.579481125 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-04-17
# close 46.14279604 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 47.610975914 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 48.449935842 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-04-18
# close 44.84734321 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 46.833704216 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 48.1168194 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-04-19
# close 45.46422551 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 46.216821916 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 47.851560011 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-04-22
# close 42.74994339 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 45.168122006 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 47.37656064 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-04-23
# close 42.93500808 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 44.427863246 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 46.45123719 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-04-24
# close 42.93500808 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 43.786305654 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 45.698640784 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-04-25
# close 42.68825516 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 43.354488044 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 45.094096130000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-04-26
# close 42.99669631 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 42.860982203999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 44.53890206 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# datetime 2019-04-29
# close 43.36682569 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 42.984358664 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 44.076240335 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# datetime 2019-04-30
# close 42.93500808 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 42.984358664 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 43.706110955 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-06
# close 38.61683198 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 42.120723444 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 42.953514549 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-07
# close 40.15903773 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 41.614879958 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 42.484684001 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-08
# close 40.1590375 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 41.047348196 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 41.9541652 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-09
# close 40.22329196 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.41864145 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 41.701500057 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-10
# close 41.1228544 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.056210713999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 41.520284689 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# datetime 2019-05-13
# close 39.90201966 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.31324825 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 41.216985847000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-14
# close 39.5164929 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.184739284 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.899809620999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-15
# close 40.35180088 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.22329196 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.635320078 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# datetime 2019-05-16
# close 40.60881872 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.300397312 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.359519381 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# datetime 2019-05-17
# close 39.96627412 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.069081256000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.062645985 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2019-05-20
# close 39.38798398 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 39.96627412 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.139761185 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-21
# close 39.96627412 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.056230364 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.120484824 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-22
# close 39.38798398 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 39.863466984 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.043379472000005 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-23
# close 38.61693046 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 39.465089332000005 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 39.882743321999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-24
# close 37.52460464 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 38.976755436000005 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 39.522918346 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-27
# close 38.42416708 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 38.783992056 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 39.375133088 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-28
# close 38.552676 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 38.50127243199999 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 39.278751398 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# datetime 2019-05-29
# close 37.9101314 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 38.205701915999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 39.03458445 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-30
# close 38.03864032 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 38.090043888 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 38.777566609999994 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-05-31
# close 38.03864032 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 38.192851024 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 38.58480323 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-06-03
# close 37.71736802 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 38.051491211999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 38.417741633999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-06-04
# close 36.68929666 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 37.678815344 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 38.090043888 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-06-05
# close 37.52460464 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 37.601709991999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 37.903705953999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-06-06
# close 36.6250422 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 37.318990368 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 37.704517128 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-06-10
# close 37.97438586 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 37.306139476 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 37.74949525 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# datetime 2019-06-11
# close 39.96627412 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 37.755920696 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 37.903705953999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# datetime 2019-06-12
# close 39.96627412 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 38.411316188 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 38.045065766 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-06-13
# close 39.77351074 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 38.861097408 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 38.2314037 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-06-14
# close 40.93009102 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 39.722107172 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 38.52054877 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-06-17
# close 40.54456426 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.236142852 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 38.771141164 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-06-18
# close 40.22329196 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.28754642 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 39.021733558 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-06-19
# close 40.22329196 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.338949988 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 39.375133088 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-06-20
# close 41.1228544 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.60881872 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 39.734958064 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-06-21
# close 41.18710886 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.660222288 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.191164730000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-06-24
# close 41.4441267 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.840134776 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.538138814 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-06-25
# close 40.60881872 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.917240128 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.602393274 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-06-26
# close 40.60881872 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.99434548000001 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.666647734 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2019-06-27
# close 40.93009102 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.955792804 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.782305762 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-06-28
# close 39.96627412 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.711625856 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.685924072 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2019-07-01
# close 40.73732764 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.570266044 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.705200409999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# datetime 2019-07-02
# close 40.28754642 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.506011584 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.711625856 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-07-03
# close 41.37987224 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.660222288 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.827283884 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# datetime 2019-07-04
# close 42.0866713 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.891538344 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.923665574 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# datetime 2019-07-05
# close 41.1228544 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 41.1228544 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.917240127999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-07-08
# close 39.58074736 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.891538344 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.730902193999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2019-07-09
# close 39.5164929 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.737327640000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.621669612 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2019-07-10
# close 37.71736802 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.004826795999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.332524542 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2019-07-11
# close 39.5164929 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 39.490791116000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.191164730000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# datetime 2019-07-12
# close 39.38798398 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 39.143817032 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.133335716 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# datetime 2019-07-15
# close 40.22329196 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 39.272325952 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.081932148 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# datetime 2019-07-16
# close 41.25136332 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 39.619300036000006 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.178313838 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# datetime 2019-07-17
# close 41.18710886 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.313248204000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 40.1590375 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2019-07-18
# close 40.22329196 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 40.454608015999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# ...
# sma5 34.795746648 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 34.863258767999994 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# datetime 2020-12-01
# close 35.1063024 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 34.876761192 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 34.863258767999994 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2020-12-02
# close 35.03879028 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 34.94427331199999 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 34.87000998 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2020-12-03
# close 34.70122968 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 34.957775735999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 34.863258767999994 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2020-12-04
# close 34.36366908 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 34.809249072 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 34.822751496 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-07
# close 33.89108424 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 34.620215136 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 34.707980892 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-08
# close 33.89108424 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 34.377171504 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 34.626966347999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-09
# close 33.55352364 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 34.080118176 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 34.512195743999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-10
# close 33.55352364 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 33.850576968 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 34.404176352 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-11
# close 33.14845092 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 33.607533336 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 34.208391203999994 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-14
# close 33.4184994 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 33.513016368 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 34.066615752000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-15
# close 33.21596304 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 33.377992128 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 33.877581815999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-16
# close 32.87840244 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 33.242967887999995 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 33.661543032 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-17
# close 32.94591456 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 33.121446072000005 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 33.48601152 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-18
# close 32.54084184 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 32.999924256 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 33.303728796 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-21
# close 32.54084184 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 32.824392744 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 33.168704556 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-22
# close 32.13576912 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 32.60835396 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 32.993173044 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-23
# close 31.93323276 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 32.419320024 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 32.831143956 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-24
# close 31.19059944 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 32.068257 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 32.594851536 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-25
# close 31.25811156 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 31.811710943999998 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 32.4058176 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-28
# close 31.12308732 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 31.52816004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 32.176276392 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2020-12-29
# close 31.59567216 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 31.420140648 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 32.014247303999994 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# datetime 2020-12-30
# close 31.52816004 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 31.339126104 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 31.879223064 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# datetime 2020-12-31
# close 31.25811156 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 31.352628528000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 31.710442764 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2021-01-04
# close 30.0428934 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 31.109584896 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 31.460647919999996 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2021-01-05
# close 30.11040552 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 30.907048536 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 31.217604288 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2021-01-06
# close 30.0428934 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 30.596492784 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 31.008316716000003 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2021-01-07
# close 29.84035704 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 30.258932184000003 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 30.799029144000002 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2021-01-08
# close 29.97538128 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 30.002386128 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 30.677507328 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2021-01-11
# close 29.63782068 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 29.921371584000003 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 30.51547824 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2021-01-12
# close 29.63782068 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 29.826854616000002 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 30.366951576 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2021-01-13
# close 29.90786916 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 29.799849768 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 30.198171276 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# datetime 2021-01-14
# close 30.44796612 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 29.921371584000003 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 30.090151884 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# datetime 2021-01-15
# close 30.44796612 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 30.015888552 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 30.009137340000002 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2021-01-18
# close 30.44796612 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 30.177917639999997 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 30.049644612 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2021-01-19
# close 31.12308732 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 30.474970968 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 30.150912792000003 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿5日均线------
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2021-01-20
# close 30.58299036 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 30.609995207999997 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 30.204922488 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2021-01-21
# close 30.31294188 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 30.582990360000004 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 30.252180972 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------收盘价上穿10日均线------
# ------ buy ------
# datetime 2021-01-22
# close 29.77284492 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 30.44796612 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 30.231927336000002 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 1.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# ------ buy ------
# datetime 2021-01-25
# close 28.96269948 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 30.150912792000003 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 30.164415216 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2021-01-26
# close 28.76016312 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 29.678327952 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 30.07664946 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2021-01-27
# close 28.89518736 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 29.340767352 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 29.97538128 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>
# datetime 2021-01-28
# close 28.76016312 <backtrader.linebuffer.LineBuffer object at 0x7f4dc71a5100>
# sma5 29.0302116 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5760>
# sma10 29.806600980000002 <backtrader.indicators.sma.SimpleMovingAverage object at 0x7f4dc71a5070>
# buy_sig 0.0 <backtrader.linebuffer.LinesOperation object at 0x7f4dc7199340>

# %% [markdown]
# # 四、好用的运算指标

# %%
import backtrader.indicators as btind # 导入策略分析模块
class TestStrategy(bt.Strategy):
    
    def __init__(self):
        self.sma5 = btind.SimpleMovingAverage(period=5) # 5日均线
        self.sma10 = btind.SimpleMovingAverage(period=10) # 10日均线
        # bt.And 中所有条件都满足时返回 1；有一个条件不满足就返回 0
        self.And = bt.And(self.data>self.sma5, self.data>self.sma10, self.sma5>self.sma10)
        # bt.Or 中有一个条件满足时就返回 1；所有条件都不满足时返回 0
        self.Or = bt.Or(self.data>self.sma5, self.data>self.sma10, self.sma5>self.sma10)
        # bt.If(a, b, c) 如果满足条件 a，就返回 b，否则返回 c
        self.If = bt.If(self.data>self.sma5,1000, 5000)
        # bt.All,同 bt.And
        self.All = bt.All(self.data>self.sma5, self.data>self.sma10, self.sma5>self.sma10)
        # bt.Any，同 bt.Or
        self.Any = bt.Any(self.data>self.sma5, self.data>self.sma10, self.sma5>self.sma10)
        # bt.Max，返回同一时刻所有指标中的最大值
        self.Max = bt.Max(self.data, self.sma10, self.sma5)
        # bt.Min，返回同一时刻所有指标中的最小值
        self.Min = bt.Min(self.data, self.sma10, self.sma5)
        # bt.Sum，对同一时刻所有指标进行求和
        self.Sum = bt.Sum(self.data, self.sma10, self.sma5)
        # bt.Cmp(a,b), 如果 a>b ，返回 1；否则返回 -1
        self.Cmp = bt.Cmp(self.data, self.sma5)

        
    def next(self):
        print('---------- datetime',self.data.datetime.date(0), '------------------')
        print('close:', self.data[0], 'ma5:', self.sma5[0], 'ma10:', self.sma10[0])
        print('close>ma5',self.data>self.sma5, 'close>ma10',self.data>self.sma10, 'ma5>ma10', self.sma5>self.sma10)
        print('self.And', self.And[0], self.data>self.sma5 and self.data>self.sma10 and self.sma5>self.sma10)
        print('self.Or', self.Or[0], self.data>self.sma5 or self.data>self.sma10 or self.sma5>self.sma10)
        print('self.If', self.If[0], 1000 if self.data>self.sma5 else 5000)
        print('self.All',self.All[0], self.data>self.sma5 and self.data>self.sma10 and self.sma5>self.sma10)
        print('self.Any', self.Any[0], self.data>self.sma5 or self.data>self.sma10 or self.sma5>self.sma10)
        print('self.Max',self.Max[0], max([self.data[0], self.sma10[0], self.sma5[0]]))
        print('self.Min', self.Min[0], min([self.data[0], self.sma10[0], self.sma5[0]]))
        print('self.Sum', self.Sum[0], sum([self.data[0], self.sma10[0], self.sma5[0]]))
        print('self.Cmp', self.Cmp[0], 1 if self.data>self.sma5 else -1)  
        
cerebro3 = bt.Cerebro()
st_date = datetime.datetime(2019,1,2)
ed_date = datetime.datetime(2021,1,28)
datafeed1 = bt.feeds.PandasData(dataname=data1, fromdate=st_date, todate=ed_date)
cerebro3.adddata(datafeed1, name='600466.SH')

cerebro3.addstrategy(TestStrategy)
rasult = cerebro3.run()
# Out:
# ---------- datetime 2019-01-15 ------------------
# close: 33.06489128 ma5: 33.18826774 ma10: 33.101904218
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 33.18826774 33.18826774
# self.Min 33.06489128 33.06489128
# self.Sum 99.355063238 99.355063238
# self.Cmp -1.0 -1
# ---------- datetime 2019-01-16 ------------------
# close: 32.63307367 ma5: 32.966190112 ma10: 33.12657951
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 33.12657951 33.12657951
# self.Min 32.63307367 32.63307367
# self.Sum 98.72584329200001 98.72584329200001
# self.Cmp -1.0 -1
# ---------- datetime 2019-01-17 ------------------
# close: 32.0778796 ma5: 32.682424254 ma10: 33.151254802
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 33.151254802 33.151254802
# self.Min 32.0778796 32.0778796
# self.Sum 97.911558656 97.911558656
# self.Cmp -1.0 -1
# ---------- datetime 2019-01-18 ------------------
# close: 32.75645013 ma5: 32.608398378 ma10: 33.077228926
# close>ma5 True close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 33.077228926 33.077228926
# self.Min 32.608398378 32.608398378
# self.Sum 98.442077434 98.442077434
# self.Cmp 1.0 1
# ---------- datetime 2019-01-21 ------------------
# close: 32.44800898 ma5: 32.596060732 ma10: 32.960021289
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 32.960021289 32.960021289
# self.Min 32.44800898 32.44800898
# self.Sum 98.00409100099999 98.00409100099999
# self.Cmp -1.0 -1
# ---------- datetime 2019-01-22 ------------------
# close: 32.44800898 ma5: 32.472684271999995 ma10: 32.830476006
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 32.830476006 32.830476006
# self.Min 32.44800898 32.44800898
# self.Sum 97.75116925799999 97.75116925799999
# self.Cmp -1.0 -1
# ---------- datetime 2019-01-23 ------------------
# close: 32.50969721 ma5: 32.44800898 ma10: 32.707099546
# close>ma5 True close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 32.707099546 32.707099546
# self.Min 32.44800898 32.44800898
# self.Sum 97.664805736 97.664805736
# self.Cmp 1.0 1
# ---------- datetime 2019-01-24 ------------------
# close: 32.38632075 ma5: 32.50969721 ma10: 32.596060732
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 32.596060732 32.596060732
# self.Min 32.38632075 32.38632075
# self.Sum 97.492078692 97.49207869199999
# self.Cmp -1.0 -1
# ---------- datetime 2019-01-25 ------------------
# close: 33.06489128 ma5: 32.57138544 ma10: 32.589891909
# close>ma5 True close>ma10 True ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 33.06489128 33.06489128
# self.Min 32.57138544 32.57138544
# self.Sum 98.226168629 98.226168629
# self.Cmp 1.0 1
# ---------- datetime 2019-01-28 ------------------
# close: 33.86683827 ma5: 32.855151297999996 ma10: 32.725606015
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 33.86683827 33.86683827
# self.Min 32.725606015 32.725606015
# self.Sum 99.447595583 99.447595583
# self.Cmp 1.0 1
# ---------- datetime 2019-01-29 ------------------
# close: 34.79216172 ma5: 33.323981846 ma10: 32.898333058999995
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 34.79216172 34.79216172
# self.Min 32.898333058999995 32.898333058999995
# self.Sum 101.014476625 101.01447662500001
# self.Cmp 1.0 1
# ---------- datetime 2019-01-30 ------------------
# close: 34.23696765 ma5: 33.669435934 ma10: 33.058722457
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 34.23696765 34.23696765
# self.Min 33.058722457 33.058722457
# self.Sum 100.96512604099999 100.96512604099999
# self.Cmp 1.0 1
# ---------- datetime 2019-01-31 ------------------
# close: 34.23696765 ma5: 34.039565314 ma10: 33.274631262
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 34.23696765 34.23696765
# self.Min 33.274631262 33.274631262
# self.Sum 101.551164226 101.551164226
# self.Cmp 1.0 1
# ---------- datetime 2019-02-01 ------------------
# close: 34.73047349 ma5: 34.372681756 ma10: 33.472033598
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 34.73047349 34.73047349
# self.Min 33.472033598 33.472033598
# self.Sum 102.575188844 102.575188844
# self.Cmp 1.0 1
# ---------- datetime 2019-02-11 ------------------
# close: 35.71748517 ma5: 34.742811136 ma10: 33.798981217
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 35.71748517 35.71748517
# self.Min 33.798981217 33.798981217
# self.Sum 104.25927752300001 104.25927752300001
# self.Cmp 1.0 1
# ---------- datetime 2019-02-12 ------------------
# close: 35.65579694 ma5: 34.91553818 ma10: 34.119760013000004
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 35.65579694 35.65579694
# self.Min 34.119760013000004 34.119760013000004
# self.Sum 104.691095133 104.691095133
# self.Cmp 1.0 1
# ---------- datetime 2019-02-13 ------------------
# close: 36.3960557 ma5: 35.34735579 ma10: 34.508395862
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 36.3960557 36.3960557
# self.Min 34.508395862 34.508395862
# self.Sum 106.251807352 106.25180735199999
# self.Cmp 1.0 1
# ---------- datetime 2019-02-14 ------------------
# close: 36.14930278 ma5: 35.729822816 ma10: 34.884694065000005
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 36.14930278 36.14930278
# self.Min 34.884694065000005 34.884694065000005
# self.Sum 106.76381966100001 106.76381966100001
# self.Cmp 1.0 1
# ---------- datetime 2019-02-15 ------------------
# close: 34.91553818 ma5: 35.766835754 ma10: 35.069758754999995
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 35.766835754 35.766835754
# self.Min 34.91553818 34.91553818
# self.Sum 105.75213268899999 105.75213268899999
# self.Cmp -1.0 -1
# ---------- datetime 2019-02-18 ------------------
# close: 35.90254986 ma5: 35.803848691999995 ma10: 35.273329914
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 35.90254986 35.90254986
# self.Min 35.273329914 35.273329914
# self.Sum 106.979728466 106.97972846600001
# self.Cmp 1.0 1
# ---------- datetime 2019-02-19 ------------------
# close: 35.10060287 ma5: 35.692809878000006 ma10: 35.304174029
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 35.692809878000006 35.692809878000006
# self.Min 35.10060287 35.10060287
# self.Sum 106.097586777 106.09758677700002
# self.Cmp -1.0 -1
# ---------- datetime 2019-02-20 ------------------
# close: 35.40904402 ma5: 35.495407541999995 ma10: 35.421381666
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 35.495407541999995 35.495407541999995
# self.Min 35.40904402 35.40904402
# self.Sum 106.325833228 106.32583322800001
# self.Cmp -1.0 -1
# ---------- datetime 2019-02-21 ------------------
# close: 34.85384995 ma5: 35.236316976 ma10: 35.483069896
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 35.483069896 35.483069896
# self.Min 34.85384995 34.85384995
# self.Sum 105.573236822 105.573236822
# self.Cmp -1.0 -1
# ---------- datetime 2019-02-22 ------------------
# close: 35.1622911 ma5: 35.28566756 ma10: 35.526251657
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 35.526251657 35.526251657
# self.Min 35.1622911 35.1622911
# self.Sum 105.974210317 105.974210317
# self.Cmp -1.0 -1
# ---------- datetime 2019-02-25 ------------------
# close: 37.012938 ma5: 35.507745188 ma10: 35.65579694
# close>ma5 True close>ma10 True ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 37.012938 37.012938
# self.Min 35.507745188 35.507745188
# self.Sum 108.17648012800001 108.17648012800001
# self.Cmp 1.0 1
# ---------- datetime 2019-02-26 ------------------
# close: 37.75319676 ma5: 36.038263966 ma10: 35.865536922000004
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 37.75319676 37.75319676
# self.Min 35.865536922000004 35.865536922000004
# self.Sum 109.65699764800002 109.656997648
# self.Cmp 1.0 1
# ---------- datetime 2019-02-27 ------------------
# close: 38.49345552 ma5: 36.655146265999996 ma10: 36.075276904
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 38.49345552 38.49345552
# self.Min 36.075276904 36.075276904
# self.Sum 111.22387868999999 111.22387868999999
# self.Cmp 1.0 1
# ---------- datetime 2019-02-28 ------------------
# close: 38.30839083 ma5: 37.346054442 ma10: 36.291185709000004
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 38.30839083 38.30839083
# self.Min 36.291185709000004 36.291185709000004
# self.Sum 111.94563098100001 111.945630981
# self.Cmp 1.0 1
# ---------- datetime 2019-03-01 ------------------
# close: 38.61683198 ma5: 38.036962618000004 ma10: 36.661315089
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 38.61683198 38.61683198
# self.Min 36.661315089 36.661315089
# self.Sum 113.315109687 113.315109687
# self.Cmp 1.0 1
# ---------- datetime 2019-03-04 ------------------
# close: 39.17202605 ma5: 38.468780228 ma10: 36.988262708
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 39.17202605 39.17202605
# self.Min 36.988262708 36.988262708
# self.Sum 114.629068986 114.62906898600001
# self.Cmp 1.0 1
# ---------- datetime 2019-03-05 ------------------
# close: 41.88630817 ma5: 39.295402509999995 ma10: 37.666833237999995
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 41.88630817 41.88630817
# self.Min 37.666833237999995 37.666833237999995
# self.Sum 118.84854391799999 118.84854391799999
# self.Cmp 1.0 1
# ---------- datetime 2019-03-06 ------------------
# close: 42.25643755 ma5: 40.047998916 ma10: 38.351572591
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 42.25643755 42.25643755
# self.Min 38.351572591 38.351572591
# self.Sum 120.656009057 120.65600905699999
# self.Cmp 1.0 1
# ---------- datetime 2019-03-07 ------------------
# close: 41.45449056 ma5: 40.677218862000004 ma10: 39.011636652
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 41.45449056 41.45449056
# self.Min 39.011636652 39.011636652
# self.Sum 121.14334607400001 121.14334607400001
# self.Cmp 1.0 1
# ---------- datetime 2019-03-08 ------------------
# close: 38.55514375 ma5: 40.664881216000005 ma10: 39.350921917
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.664881216000005 40.664881216000005
# self.Min 38.55514375 38.55514375
# self.Sum 118.570946883 118.570946883
# self.Cmp -1.0 -1
# ---------- datetime 2019-03-11 ------------------
# close: 39.23371428 ma5: 40.677218862000004 ma10: 39.572999545
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.677218862000004 40.677218862000004
# self.Min 39.23371428 39.23371428
# self.Sum 119.483932687 119.483932687
# self.Cmp -1.0 -1
# ---------- datetime 2019-03-12 ------------------
# close: 40.52916711 ma5: 40.40579065 ma10: 39.85059658
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 40.52916711 40.52916711
# self.Min 39.85059658 39.85059658
# self.Sum 120.78555434 120.78555434
# self.Cmp 1.0 1
# ---------- datetime 2019-03-13 ------------------
# close: 42.31812578 ma5: 40.418128296000006 ma10: 40.233063606
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 42.31812578 42.31812578
# self.Min 40.233063606 40.233063606
# self.Sum 122.96931768200001 122.96931768200001
# self.Cmp 1.0 1
# ---------- datetime 2019-03-14 ------------------
# close: 41.20773764 ma5: 40.368777712 ma10: 40.522998287
# close>ma5 True close>ma10 True ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 41.20773764 41.20773764
# self.Min 40.368777712 40.368777712
# self.Sum 122.09951363900001 122.09951363900001
# self.Cmp 1.0 1
# ---------- datetime 2019-03-15 ------------------
# close: 42.62656693 ma5: 41.183062348 ma10: 40.923971782
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 42.62656693 42.62656693
# self.Min 40.923971782 40.923971782
# self.Sum 124.73360106000001 124.73360106000001
# self.Cmp 1.0 1
# ---------- datetime 2019-03-18 ------------------
# close: 44.47721383 ma5: 42.231762258 ma10: 41.454490559999996
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 44.47721383 44.47721383
# self.Min 41.454490559999996 41.454490559999996
# self.Sum 128.163466648 128.163466648
# self.Cmp 1.0 1
# ---------- datetime 2019-03-19 ------------------
# close: 44.60059029 ma5: 43.046046894 ma10: 41.725918772
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 44.60059029 44.60059029
# self.Min 41.725918772 41.725918772
# self.Sum 129.37255595599999 129.37255595599999
# self.Cmp 1.0 1
# ---------- datetime 2019-03-20 ------------------
# close: 44.72396675 ma5: 43.527215088000005 ma10: 41.972671692
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 44.72396675 44.72396675
# self.Min 41.972671692 41.972671692
# self.Sum 130.22385353 130.22385352999999
# self.Cmp 1.0 1
# ---------- datetime 2019-03-21 ------------------
# close: 46.14279604 ma5: 44.514226768 ma10: 42.44150224
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 46.14279604 46.14279604
# self.Min 42.44150224 42.44150224
# self.Sum 133.098525048 133.098525048
# self.Cmp 1.0 1
# ---------- datetime 2019-03-22 ------------------
# close: 45.71097843 ma5: 45.131109068 ma10: 43.157085708
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 45.71097843 45.71097843
# self.Min 43.157085708 43.157085708
# self.Sum 133.999173206 133.999173206
# self.Cmp 1.0 1
# ---------- datetime 2019-03-25 ------------------
# close: 45.6492902 ma5: 45.365524342 ma10: 43.7986433
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 45.6492902 45.6492902
# self.Min 43.7986433 43.7986433
# self.Sum 134.813457842 134.813457842
# self.Cmp 1.0 1
# ---------- datetime 2019-03-26 ------------------
# close: 44.47721383 ma5: 45.340849049999996 ma10: 44.193447972
# close>ma5 False close>ma10 True ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 45.340849049999996 45.340849049999996
# self.Min 44.193447972 44.193447972
# self.Sum 134.011510852 134.011510852
# self.Cmp -1.0 -1
# ---------- datetime 2019-03-27 ------------------
# close: 45.58760197 ma5: 45.513576094 ma10: 44.520395590999996
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 45.58760197 45.58760197
# self.Min 44.520395590999996 44.520395590999996
# self.Sum 135.621573655 135.621573655
# self.Cmp 1.0 1
# ---------- datetime 2019-03-28 ------------------
# close: 43.49020215 ma5: 44.983057316 ma10: 44.748642042
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 44.983057316 44.983057316
# self.Min 43.49020215 43.49020215
# self.Sum 133.221901508 133.221901508
# self.Cmp -1.0 -1
# ---------- datetime 2019-03-29 ------------------
# close: 45.52591374 ma5: 44.946044377999996 ma10: 45.038576723
# close>ma5 True close>ma10 True ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 45.52591374 45.52591374
# self.Min 44.946044377999996 44.946044377999996
# self.Sum 135.51053484099998 135.51053484099998
# self.Cmp 1.0 1
# ---------- datetime 2019-04-01 ------------------
# close: 47.74669002 ma5: 45.365524342 ma10: 45.365524342
# close>ma5 True close>ma10 True ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 47.74669002 47.74669002
# self.Min 45.365524342 45.365524342
# self.Sum 138.477738704 138.477738704
# self.Cmp 1.0 1
# ---------- datetime 2019-04-02 ------------------
# close: 47.43824887 ma5: 45.95773135 ma10: 45.6492902
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 47.43824887 47.43824887
# self.Min 45.6492902 45.6492902
# self.Sum 139.04527042 139.04527042
# self.Cmp 1.0 1
# ---------- datetime 2019-04-03 ------------------
# close: 48.17850763 ma5: 46.475912482 ma10: 45.994744288
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 48.17850763 48.17850763
# self.Min 45.994744288 45.994744288
# self.Sum 140.6491644 140.64916440000002
# self.Cmp 1.0 1
# ---------- datetime 2019-04-04 ------------------
# close: 48.1168194 ma5: 47.401235932 ma10: 46.192146623999996
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 48.1168194 48.1168194
# self.Min 46.192146623999996 46.192146623999996
# self.Sum 141.710201956 141.710201956
# self.Cmp 1.0 1
# ---------- datetime 2019-04-08 ------------------
# close: 47.4999371 ma5: 47.796040604 ma10: 46.371042491000004
# close>ma5 False close>ma10 True ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 47.796040604 47.796040604
# self.Min 46.371042491000004 46.371042491000004
# self.Sum 141.667020195 141.66702019500002
# self.Cmp -1.0 -1
# ---------- datetime 2019-04-09 ------------------
# close: 52.18824258 ma5: 48.684351116 ma10: 47.024937729
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 52.18824258 52.18824258
# self.Min 47.024937729 47.024937729
# self.Sum 147.897531425 147.897531425
# self.Cmp 1.0 1
# ---------- datetime 2019-04-10 ------------------
# close: 50.46097214 ma5: 49.288895769999996 ma10: 47.62331356
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 50.46097214 50.46097214
# self.Min 47.62331356 47.62331356
# self.Sum 147.37318147 147.37318147000002
# self.Cmp 1.0 1
# ---------- datetime 2019-04-11 ------------------
# close: 48.7337017 ma5: 49.399934584 ma10: 47.937923533
# close>ma5 False close>ma10 True ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 49.399934584 49.399934584
# self.Min 47.937923533 47.937923533
# self.Sum 146.071559817 146.071559817
# self.Cmp -1.0 -1
# ---------- datetime 2019-04-12 ------------------
# close: 48.54863701 ma5: 49.486298106 ma10: 48.443767019
# close>ma5 False close>ma10 True ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 49.486298106 49.486298106
# self.Min 48.443767019 48.443767019
# self.Sum 146.478702135 146.478702135
# self.Cmp -1.0 -1
# ---------- datetime 2019-04-15 ------------------
# close: 47.99344294 ma5: 49.584999274 ma10: 48.690519939
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 49.584999274 49.584999274
# self.Min 47.99344294 47.99344294
# self.Sum 146.268962153 146.26896215300002
# self.Cmp -1.0 -1
# ---------- datetime 2019-04-16 ------------------
# close: 46.63630188 ma5: 48.474611134 ma10: 48.579481125
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 48.579481125 48.579481125
# self.Min 46.63630188 46.63630188
# self.Sum 143.690394139 143.69039413899998
# self.Cmp -1.0 -1
# ---------- datetime 2019-04-17 ------------------
# close: 46.14279604 ma5: 47.610975914 ma10: 48.449935842
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 48.449935842 48.449935842
# self.Min 46.14279604 46.14279604
# self.Sum 142.203707796 142.203707796
# self.Cmp -1.0 -1
# ---------- datetime 2019-04-18 ------------------
# close: 44.84734321 ma5: 46.833704216 ma10: 48.1168194
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 48.1168194 48.1168194
# self.Min 44.84734321 44.84734321
# self.Sum 139.797866826 139.797866826
# self.Cmp -1.0 -1
# ---------- datetime 2019-04-19 ------------------
# close: 45.46422551 ma5: 46.216821916 ma10: 47.851560011
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 47.851560011 47.851560011
# self.Min 45.46422551 45.46422551
# self.Sum 139.532607437 139.532607437
# self.Cmp -1.0 -1
# ---------- datetime 2019-04-22 ------------------
# close: 42.74994339 ma5: 45.168122006 ma10: 47.37656064
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 47.37656064 47.37656064
# self.Min 42.74994339 42.74994339
# self.Sum 135.294626036 135.294626036
# self.Cmp -1.0 -1
# ---------- datetime 2019-04-23 ------------------
# close: 42.93500808 ma5: 44.427863246 ma10: 46.45123719
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 46.45123719 46.45123719
# self.Min 42.93500808 42.93500808
# self.Sum 133.814108516 133.814108516
# self.Cmp -1.0 -1
# ---------- datetime 2019-04-24 ------------------
# close: 42.93500808 ma5: 43.786305654 ma10: 45.698640784
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 45.698640784 45.698640784
# self.Min 42.93500808 42.93500808
# self.Sum 132.419954518 132.419954518
# self.Cmp -1.0 -1
# ---------- datetime 2019-04-25 ------------------
# close: 42.68825516 ma5: 43.354488044 ma10: 45.094096130000004
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 45.094096130000004 45.094096130000004
# self.Min 42.68825516 42.68825516
# self.Sum 131.136839334 131.136839334
# self.Cmp -1.0 -1
# ---------- datetime 2019-04-26 ------------------
# close: 42.99669631 ma5: 42.860982203999995 ma10: 44.53890206
# close>ma5 True close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 44.53890206 44.53890206
# self.Min 42.860982203999995 42.860982203999995
# self.Sum 130.39658057399998 130.39658057399998
# self.Cmp 1.0 1
# ---------- datetime 2019-04-29 ------------------
# close: 43.36682569 ma5: 42.984358664 ma10: 44.076240335
# close>ma5 True close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 44.076240335 44.076240335
# self.Min 42.984358664 42.984358664
# self.Sum 130.427424689 130.42742468900002
# self.Cmp 1.0 1
# ---------- datetime 2019-04-30 ------------------
# close: 42.93500808 ma5: 42.984358664 ma10: 43.706110955
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 43.706110955 43.706110955
# self.Min 42.93500808 42.93500808
# self.Sum 129.625477699 129.625477699
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-06 ------------------
# close: 38.61683198 ma5: 42.120723444 ma10: 42.953514549
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 42.953514549 42.953514549
# self.Min 38.61683198 38.61683198
# self.Sum 123.691069973 123.691069973
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-07 ------------------
# close: 40.15903773 ma5: 41.614879958 ma10: 42.484684001
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 42.484684001 42.484684001
# self.Min 40.15903773 40.15903773
# self.Sum 124.258601689 124.258601689
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-08 ------------------
# close: 40.1590375 ma5: 41.047348196 ma10: 41.9541652
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 41.9541652 41.9541652
# self.Min 40.1590375 40.1590375
# self.Sum 123.16055089599999 123.16055089599999
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-09 ------------------
# close: 40.22329196 ma5: 40.41864145 ma10: 41.701500057
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 41.701500057 41.701500057
# self.Min 40.22329196 40.22329196
# self.Sum 122.343433467 122.34343346699998
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-10 ------------------
# close: 41.1228544 ma5: 40.056210713999995 ma10: 41.520284689
# close>ma5 True close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 41.520284689 41.520284689
# self.Min 40.056210713999995 40.056210713999995
# self.Sum 122.69934980299999 122.69934980299999
# self.Cmp 1.0 1
# ---------- datetime 2019-05-13 ------------------
# close: 39.90201966 ma5: 40.31324825 ma10: 41.216985847000004
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 41.216985847000004 41.216985847000004
# self.Min 39.90201966 39.90201966
# self.Sum 121.43225375700001 121.432253757
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-14 ------------------
# close: 39.5164929 ma5: 40.184739284 ma10: 40.899809620999996
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 40.899809620999996 40.899809620999996
# self.Min 39.5164929 39.5164929
# self.Sum 120.601041805 120.60104180500001
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-15 ------------------
# close: 40.35180088 ma5: 40.22329196 ma10: 40.635320078
# close>ma5 True close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.635320078 40.635320078
# self.Min 40.22329196 40.22329196
# self.Sum 121.210412918 121.21041291799999
# self.Cmp 1.0 1
# ---------- datetime 2019-05-16 ------------------
# close: 40.60881872 ma5: 40.300397312 ma10: 40.359519381
# close>ma5 True close>ma10 True ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.60881872 40.60881872
# self.Min 40.300397312 40.300397312
# self.Sum 121.268735413 121.268735413
# self.Cmp 1.0 1
# ---------- datetime 2019-05-17 ------------------
# close: 39.96627412 ma5: 40.069081256000004 ma10: 40.062645985
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.069081256000004 40.069081256000004
# self.Min 39.96627412 39.96627412
# self.Sum 120.098001361 120.098001361
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-20 ------------------
# close: 39.38798398 ma5: 39.96627412 ma10: 40.139761185
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 40.139761185 40.139761185
# self.Min 39.38798398 39.38798398
# self.Sum 119.49401928500001 119.49401928500001
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-21 ------------------
# close: 39.96627412 ma5: 40.056230364 ma10: 40.120484824
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 40.120484824 40.120484824
# self.Min 39.96627412 39.96627412
# self.Sum 120.14298930800001 120.142989308
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-22 ------------------
# close: 39.38798398 ma5: 39.863466984 ma10: 40.043379472000005
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 40.043379472000005 40.043379472000005
# self.Min 39.38798398 39.38798398
# self.Sum 119.29483043600001 119.294830436
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-23 ------------------
# close: 38.61693046 ma5: 39.465089332000005 ma10: 39.882743321999996
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 39.882743321999996 39.882743321999996
# self.Min 38.61693046 38.61693046
# self.Sum 117.964763114 117.96476311400001
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-24 ------------------
# close: 37.52460464 ma5: 38.976755436000005 ma10: 39.522918346
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 39.522918346 39.522918346
# self.Min 37.52460464 37.52460464
# self.Sum 116.02427842200001 116.024278422
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-27 ------------------
# close: 38.42416708 ma5: 38.783992056 ma10: 39.375133088
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 39.375133088 39.375133088
# self.Min 38.42416708 38.42416708
# self.Sum 116.58329222399999 116.583292224
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-28 ------------------
# close: 38.552676 ma5: 38.50127243199999 ma10: 39.278751398
# close>ma5 True close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 39.278751398 39.278751398
# self.Min 38.50127243199999 38.50127243199999
# self.Sum 116.33269983 116.33269982999998
# self.Cmp 1.0 1
# ---------- datetime 2019-05-29 ------------------
# close: 37.9101314 ma5: 38.205701915999995 ma10: 39.03458445
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 39.03458445 39.03458445
# self.Min 37.9101314 37.9101314
# self.Sum 115.15041776599999 115.15041776599999
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-30 ------------------
# close: 38.03864032 ma5: 38.090043888 ma10: 38.777566609999994
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 38.777566609999994 38.777566609999994
# self.Min 38.03864032 38.03864032
# self.Sum 114.90625081799999 114.90625081799999
# self.Cmp -1.0 -1
# ---------- datetime 2019-05-31 ------------------
# close: 38.03864032 ma5: 38.192851024 ma10: 38.58480323
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 38.58480323 38.58480323
# self.Min 38.03864032 38.03864032
# self.Sum 114.816294574 114.81629457399998
# self.Cmp -1.0 -1
# ---------- datetime 2019-06-03 ------------------
# close: 37.71736802 ma5: 38.051491211999995 ma10: 38.417741633999995
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 38.417741633999995 38.417741633999995
# self.Min 37.71736802 37.71736802
# self.Sum 114.18660086599999 114.18660086599999
# self.Cmp -1.0 -1
# ---------- datetime 2019-06-04 ------------------
# close: 36.68929666 ma5: 37.678815344 ma10: 38.090043888
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 38.090043888 38.090043888
# self.Min 36.68929666 36.68929666
# self.Sum 112.458155892 112.458155892
# self.Cmp -1.0 -1
# ---------- datetime 2019-06-05 ------------------
# close: 37.52460464 ma5: 37.601709991999996 ma10: 37.903705953999996
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 37.903705953999996 37.903705953999996
# self.Min 37.52460464 37.52460464
# self.Sum 113.03002058599999 113.03002058599999
# self.Cmp -1.0 -1
# ---------- datetime 2019-06-06 ------------------
# close: 36.6250422 ma5: 37.318990368 ma10: 37.704517128
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 37.704517128 37.704517128
# self.Min 36.6250422 36.6250422
# self.Sum 111.648549696 111.648549696
# self.Cmp -1.0 -1
# ---------- datetime 2019-06-10 ------------------
# close: 37.97438586 ma5: 37.306139476 ma10: 37.74949525
# close>ma5 True close>ma10 True ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 37.97438586 37.97438586
# self.Min 37.306139476 37.306139476
# self.Sum 113.030020586 113.030020586
# self.Cmp 1.0 1
# ---------- datetime 2019-06-11 ------------------
# close: 39.96627412 ma5: 37.755920696 ma10: 37.903705953999996
# close>ma5 True close>ma10 True ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 39.96627412 39.96627412
# self.Min 37.755920696 37.755920696
# self.Sum 115.62590076999999 115.62590076999999
# self.Cmp 1.0 1
# ---------- datetime 2019-06-12 ------------------
# close: 39.96627412 ma5: 38.411316188 ma10: 38.045065766
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 39.96627412 39.96627412
# self.Min 38.045065766 38.045065766
# self.Sum 116.422656074 116.422656074
# self.Cmp 1.0 1
# ---------- datetime 2019-06-13 ------------------
# close: 39.77351074 ma5: 38.861097408 ma10: 38.2314037
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 39.77351074 39.77351074
# self.Min 38.2314037 38.2314037
# self.Sum 116.866011848 116.866011848
# self.Cmp 1.0 1
# ---------- datetime 2019-06-14 ------------------
# close: 40.93009102 ma5: 39.722107172 ma10: 38.52054877
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 40.93009102 40.93009102
# self.Min 38.52054877 38.52054877
# self.Sum 119.17274696199999 119.17274696199999
# self.Cmp 1.0 1
# ---------- datetime 2019-06-17 ------------------
# close: 40.54456426 ma5: 40.236142852 ma10: 38.771141164
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 40.54456426 40.54456426
# self.Min 38.771141164 38.771141164
# self.Sum 119.551848276 119.551848276
# self.Cmp 1.0 1
# ---------- datetime 2019-06-18 ------------------
# close: 40.22329196 ma5: 40.28754642 ma10: 39.021733558
# close>ma5 False close>ma10 True ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.28754642 40.28754642
# self.Min 39.021733558 39.021733558
# self.Sum 119.53257193799999 119.532571938
# self.Cmp -1.0 -1
# ---------- datetime 2019-06-19 ------------------
# close: 40.22329196 ma5: 40.338949988 ma10: 39.375133088
# close>ma5 False close>ma10 True ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.338949988 40.338949988
# self.Min 39.375133088 39.375133088
# self.Sum 119.93737503599999 119.93737503599999
# self.Cmp -1.0 -1
# ---------- datetime 2019-06-20 ------------------
# close: 41.1228544 ma5: 40.60881872 ma10: 39.734958064
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 41.1228544 41.1228544
# self.Min 39.734958064 39.734958064
# self.Sum 121.466631184 121.46663118400001
# self.Cmp 1.0 1
# ---------- datetime 2019-06-21 ------------------
# close: 41.18710886 ma5: 40.660222288 ma10: 40.191164730000004
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 41.18710886 41.18710886
# self.Min 40.191164730000004 40.191164730000004
# self.Sum 122.038495878 122.038495878
# self.Cmp 1.0 1
# ---------- datetime 2019-06-24 ------------------
# close: 41.4441267 ma5: 40.840134776 ma10: 40.538138814
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 41.4441267 41.4441267
# self.Min 40.538138814 40.538138814
# self.Sum 122.82240028999999 122.82240029
# self.Cmp 1.0 1
# ---------- datetime 2019-06-25 ------------------
# close: 40.60881872 ma5: 40.917240128 ma10: 40.602393274
# close>ma5 False close>ma10 True ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.917240128 40.917240128
# self.Min 40.602393274 40.602393274
# self.Sum 122.128452122 122.128452122
# self.Cmp -1.0 -1
# ---------- datetime 2019-06-26 ------------------
# close: 40.60881872 ma5: 40.99434548000001 ma10: 40.666647734
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.99434548000001 40.99434548000001
# self.Min 40.60881872 40.60881872
# self.Sum 122.26981193400002 122.269811934
# self.Cmp -1.0 -1
# ---------- datetime 2019-06-27 ------------------
# close: 40.93009102 ma5: 40.955792804 ma10: 40.782305762
# close>ma5 False close>ma10 True ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.955792804 40.955792804
# self.Min 40.782305762 40.782305762
# self.Sum 122.668189586 122.668189586
# self.Cmp -1.0 -1
# ---------- datetime 2019-06-28 ------------------
# close: 39.96627412 ma5: 40.711625856 ma10: 40.685924072
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.711625856 40.711625856
# self.Min 39.96627412 39.96627412
# self.Sum 121.363824048 121.363824048
# self.Cmp -1.0 -1
# ---------- datetime 2019-07-01 ------------------
# close: 40.73732764 ma5: 40.570266044 ma10: 40.705200409999996
# close>ma5 True close>ma10 True ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.73732764 40.73732764
# self.Min 40.570266044 40.570266044
# self.Sum 122.01279409399999 122.01279409399999
# self.Cmp 1.0 1
# ---------- datetime 2019-07-02 ------------------
# close: 40.28754642 ma5: 40.506011584 ma10: 40.711625856
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 40.711625856 40.711625856
# self.Min 40.28754642 40.28754642
# self.Sum 121.50518385999999 121.50518385999999
# self.Cmp -1.0 -1
# ---------- datetime 2019-07-03 ------------------
# close: 41.37987224 ma5: 40.660222288 ma10: 40.827283884
# close>ma5 True close>ma10 True ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 41.37987224 41.37987224
# self.Min 40.660222288 40.660222288
# self.Sum 122.867378412 122.867378412
# self.Cmp 1.0 1
# ---------- datetime 2019-07-04 ------------------
# close: 42.0866713 ma5: 40.891538344 ma10: 40.923665574
# close>ma5 True close>ma10 True ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 42.0866713 42.0866713
# self.Min 40.891538344 40.891538344
# self.Sum 123.90187521799999 123.90187521799999
# self.Cmp 1.0 1
# ---------- datetime 2019-07-05 ------------------
# close: 41.1228544 ma5: 41.1228544 ma10: 40.917240127999996
# close>ma5 False close>ma10 True ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 41.1228544 41.1228544
# self.Min 40.917240127999996 40.917240127999996
# self.Sum 123.16294892799999 123.16294892799999
# self.Cmp 0.0 -1
# ---------- datetime 2019-07-08 ------------------
# close: 39.58074736 ma5: 40.891538344 ma10: 40.730902193999995
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.891538344 40.891538344
# self.Min 39.58074736 39.58074736
# self.Sum 121.20318789799998 121.20318789799998
# self.Cmp -1.0 -1
# ---------- datetime 2019-07-09 ------------------
# close: 39.5164929 ma5: 40.737327640000004 ma10: 40.621669612
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.737327640000004 40.737327640000004
# self.Min 39.5164929 39.5164929
# self.Sum 120.875490152 120.87549015200001
# self.Cmp -1.0 -1
# ---------- datetime 2019-07-10 ------------------
# close: 37.71736802 ma5: 40.004826795999996 ma10: 40.332524542
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 40.332524542 40.332524542
# self.Min 37.71736802 37.71736802
# self.Sum 118.054719358 118.054719358
# self.Cmp -1.0 -1
# ---------- datetime 2019-07-11 ------------------
# close: 39.5164929 ma5: 39.490791116000004 ma10: 40.191164730000004
# close>ma5 True close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.191164730000004 40.191164730000004
# self.Min 39.490791116000004 39.490791116000004
# self.Sum 119.19844874600001 119.198448746
# self.Cmp 1.0 1
# ---------- datetime 2019-07-12 ------------------
# close: 39.38798398 ma5: 39.143817032 ma10: 40.133335716
# close>ma5 True close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.133335716 40.133335716
# self.Min 39.143817032 39.143817032
# self.Sum 118.665136728 118.66513672800001
# self.Cmp 1.0 1
# ---------- datetime 2019-07-15 ------------------
# close: 40.22329196 ma5: 39.272325952 ma10: 40.081932148
# close>ma5 True close>ma10 True ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.22329196 40.22329196
# self.Min 39.272325952 39.272325952
# self.Sum 119.57755006 119.57755006000001
# self.Cmp 1.0 1
# ---------- datetime 2019-07-16 ------------------
# close: 41.25136332 ma5: 39.619300036000006 ma10: 40.178313838
# close>ma5 True close>ma10 True ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 41.25136332 41.25136332
# self.Min 39.619300036000006 39.619300036000006
# self.Sum 121.048977194 121.048977194
# self.Cmp 1.0 1
# ---------- datetime 2019-07-17 ------------------
# close: 41.18710886 ma5: 40.313248204000004 ma10: 40.1590375
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 41.18710886 41.18710886
# self.Min 40.1590375 40.1590375
# self.Sum 121.659394564 121.65939456400001
# self.Cmp 1.0 1
# ---------- datetime 2019-07-18 ------------------
# close: 40.22329196 ma5: 40.454608015999995 ma10: 39.972699566
# close>ma5 False close>ma10 True ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.454608015999995 40.454608015999995
# self.Min 39.972699566 39.972699566
# self.Sum 120.650599542 120.650599542
# self.Cmp -1.0 -1
# ---------- datetime 2019-07-19 ------------------
# close: 41.765399 ma5: 40.93009102 ma10: 40.036954026000004
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 41.765399 41.765399
# self.Min 40.036954026000004 40.036954026000004
# self.Sum 122.73244404600001 122.73244404600001
# self.Cmp 1.0 1
# ---------- datetime 2019-07-22 ------------------
# close: 40.67307318 ma5: 41.020047264000006 ma10: 40.146186608
# close>ma5 False close>ma10 True ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 41.020047264000006 41.020047264000006
# self.Min 40.146186608 40.146186608
# self.Sum 121.83930705200001 121.83930705200001
# self.Cmp -1.0 -1
# ---------- datetime 2019-07-23 ------------------
# close: 40.67307318 ma5: 40.904389236 ma10: 40.261844636
# close>ma5 False close>ma10 True ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.904389236 40.904389236
# self.Min 40.261844636 40.261844636
# self.Sum 121.83930705200001 121.839307052
# self.Cmp -1.0 -1
# ---------- datetime 2019-07-24 ------------------
# close: 40.54456426 ma5: 40.775880316 ma10: 40.54456426
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.775880316 40.775880316
# self.Min 40.54456426 40.54456426
# self.Sum 121.865008836 121.865008836
# self.Cmp -1.0 -1
# ---------- datetime 2019-07-25 ------------------
# close: 40.09478304 ma5: 40.750178532 ma10: 40.602393274
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 40.750178532 40.750178532
# ...
# self.Max 34.863258767999994 34.863258767999994
# self.Min 34.795746648 34.795746648
# self.Sum 104.49525933599999 104.495259336
# self.Cmp 1.0 1
# ---------- datetime 2020-12-01 ------------------
# close: 35.1063024 ma5: 34.876761192 ma10: 34.863258767999994
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 35.1063024 35.1063024
# self.Min 34.863258767999994 34.863258767999994
# self.Sum 104.84632235999999 104.84632235999999
# self.Cmp 1.0 1
# ---------- datetime 2020-12-02 ------------------
# close: 35.03879028 ma5: 34.94427331199999 ma10: 34.87000998
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 35.03879028 35.03879028
# self.Min 34.87000998 34.87000998
# self.Sum 104.853073572 104.85307357199999
# self.Cmp 1.0 1
# ---------- datetime 2020-12-03 ------------------
# close: 34.70122968 ma5: 34.957775735999995 ma10: 34.863258767999994
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 34.957775735999995 34.957775735999995
# self.Min 34.70122968 34.70122968
# self.Sum 104.522264184 104.522264184
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-04 ------------------
# close: 34.36366908 ma5: 34.809249072 ma10: 34.822751496
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 34.822751496 34.822751496
# self.Min 34.36366908 34.36366908
# self.Sum 103.995669648 103.995669648
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-07 ------------------
# close: 33.89108424 ma5: 34.620215136 ma10: 34.707980892
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 34.707980892 34.707980892
# self.Min 33.89108424 33.89108424
# self.Sum 103.219280268 103.21928026799999
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-08 ------------------
# close: 33.89108424 ma5: 34.377171504 ma10: 34.626966347999996
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 34.626966347999996 34.626966347999996
# self.Min 33.89108424 33.89108424
# self.Sum 102.895222092 102.895222092
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-09 ------------------
# close: 33.55352364 ma5: 34.080118176 ma10: 34.512195743999996
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 34.512195743999996 34.512195743999996
# self.Min 33.55352364 33.55352364
# self.Sum 102.14583755999999 102.14583756
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-10 ------------------
# close: 33.55352364 ma5: 33.850576968 ma10: 34.404176352
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 34.404176352 34.404176352
# self.Min 33.55352364 33.55352364
# self.Sum 101.80827696 101.80827696
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-11 ------------------
# close: 33.14845092 ma5: 33.607533336 ma10: 34.208391203999994
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 34.208391203999994 34.208391203999994
# self.Min 33.14845092 33.14845092
# self.Sum 100.96437546 100.96437546
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-14 ------------------
# close: 33.4184994 ma5: 33.513016368 ma10: 34.066615752000004
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 34.066615752000004 34.066615752000004
# self.Min 33.4184994 33.4184994
# self.Sum 100.99813152000002 100.99813152000002
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-15 ------------------
# close: 33.21596304 ma5: 33.377992128 ma10: 33.877581815999996
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 33.877581815999996 33.877581815999996
# self.Min 33.21596304 33.21596304
# self.Sum 100.471536984 100.471536984
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-16 ------------------
# close: 32.87840244 ma5: 33.242967887999995 ma10: 33.661543032
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 33.661543032 33.661543032
# self.Min 32.87840244 32.87840244
# self.Sum 99.78291336 99.78291336
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-17 ------------------
# close: 32.94591456 ma5: 33.121446072000005 ma10: 33.48601152
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 33.48601152 33.48601152
# self.Min 32.94591456 32.94591456
# self.Sum 99.55337215200001 99.55337215200001
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-18 ------------------
# close: 32.54084184 ma5: 32.999924256 ma10: 33.303728796
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 33.303728796 33.303728796
# self.Min 32.54084184 32.54084184
# self.Sum 98.844494892 98.844494892
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-21 ------------------
# close: 32.54084184 ma5: 32.824392744 ma10: 33.168704556
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 33.168704556 33.168704556
# self.Min 32.54084184 32.54084184
# self.Sum 98.53393914 98.53393914
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-22 ------------------
# close: 32.13576912 ma5: 32.60835396 ma10: 32.993173044
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 32.993173044 32.993173044
# self.Min 32.13576912 32.13576912
# self.Sum 97.73729612400001 97.737296124
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-23 ------------------
# close: 31.93323276 ma5: 32.419320024 ma10: 32.831143956
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 32.831143956 32.831143956
# self.Min 31.93323276 31.93323276
# self.Sum 97.18369674 97.18369674
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-24 ------------------
# close: 31.19059944 ma5: 32.068257 ma10: 32.594851536
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 32.594851536 32.594851536
# self.Min 31.19059944 31.19059944
# self.Sum 95.85370797600001 95.85370797600001
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-25 ------------------
# close: 31.25811156 ma5: 31.811710943999998 ma10: 32.4058176
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 32.4058176 32.4058176
# self.Min 31.25811156 31.25811156
# self.Sum 95.475640104 95.475640104
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-28 ------------------
# close: 31.12308732 ma5: 31.52816004 ma10: 32.176276392
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 32.176276392 32.176276392
# self.Min 31.12308732 31.12308732
# self.Sum 94.82752375199999 94.827523752
# self.Cmp -1.0 -1
# ---------- datetime 2020-12-29 ------------------
# close: 31.59567216 ma5: 31.420140648 ma10: 32.014247303999994
# close>ma5 True close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 32.014247303999994 32.014247303999994
# self.Min 31.420140648 31.420140648
# self.Sum 95.030060112 95.030060112
# self.Cmp 1.0 1
# ---------- datetime 2020-12-30 ------------------
# close: 31.52816004 ma5: 31.339126104 ma10: 31.879223064
# close>ma5 True close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 31.879223064 31.879223064
# self.Min 31.339126104 31.339126104
# self.Sum 94.746509208 94.746509208
# self.Cmp 1.0 1
# ---------- datetime 2020-12-31 ------------------
# close: 31.25811156 ma5: 31.352628528000004 ma10: 31.710442764
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 31.710442764 31.710442764
# self.Min 31.25811156 31.25811156
# self.Sum 94.321182852 94.32118285199999
# self.Cmp -1.0 -1
# ---------- datetime 2021-01-04 ------------------
# close: 30.0428934 ma5: 31.109584896 ma10: 31.460647919999996
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 31.460647919999996 31.460647919999996
# self.Min 30.0428934 30.0428934
# self.Sum 92.613126216 92.613126216
# self.Cmp -1.0 -1
# ---------- datetime 2021-01-05 ------------------
# close: 30.11040552 ma5: 30.907048536 ma10: 31.217604288
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 31.217604288 31.217604288
# self.Min 30.11040552 30.11040552
# self.Sum 92.23505834400001 92.23505834400001
# self.Cmp -1.0 -1
# ---------- datetime 2021-01-06 ------------------
# close: 30.0428934 ma5: 30.596492784 ma10: 31.008316716000003
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 31.008316716000003 31.008316716000003
# self.Min 30.0428934 30.0428934
# self.Sum 91.6477029 91.64770290000001
# self.Cmp -1.0 -1
# ---------- datetime 2021-01-07 ------------------
# close: 29.84035704 ma5: 30.258932184000003 ma10: 30.799029144000002
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 30.799029144000002 30.799029144000002
# self.Min 29.84035704 29.84035704
# self.Sum 90.898318368 90.898318368
# self.Cmp -1.0 -1
# ---------- datetime 2021-01-08 ------------------
# close: 29.97538128 ma5: 30.002386128 ma10: 30.677507328
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 30.677507328 30.677507328
# self.Min 29.97538128 29.97538128
# self.Sum 90.655274736 90.655274736
# self.Cmp -1.0 -1
# ---------- datetime 2021-01-11 ------------------
# close: 29.63782068 ma5: 29.921371584000003 ma10: 30.51547824
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 30.51547824 30.51547824
# self.Min 29.63782068 29.63782068
# self.Sum 90.07467050400001 90.074670504
# self.Cmp -1.0 -1
# ---------- datetime 2021-01-12 ------------------
# close: 29.63782068 ma5: 29.826854616000002 ma10: 30.366951576
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 30.366951576 30.366951576
# self.Min 29.63782068 29.63782068
# self.Sum 89.831626872 89.831626872
# self.Cmp -1.0 -1
# ---------- datetime 2021-01-13 ------------------
# close: 29.90786916 ma5: 29.799849768 ma10: 30.198171276
# close>ma5 True close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 30.198171276 30.198171276
# self.Min 29.799849768 29.799849768
# self.Sum 89.905890204 89.905890204
# self.Cmp 1.0 1
# ---------- datetime 2021-01-14 ------------------
# close: 30.44796612 ma5: 29.921371584000003 ma10: 30.090151884
# close>ma5 True close>ma10 True ma5>ma10 False
# self.And 0.0 False
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 30.44796612 30.44796612
# self.Min 29.921371584000003 29.921371584000003
# self.Sum 90.459489588 90.459489588
# self.Cmp 1.0 1
# ---------- datetime 2021-01-15 ------------------
# close: 30.44796612 ma5: 30.015888552 ma10: 30.009137340000002
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 30.44796612 30.44796612
# self.Min 30.009137340000002 30.009137340000002
# self.Sum 90.472992012 90.47299201199999
# self.Cmp 1.0 1
# ---------- datetime 2021-01-18 ------------------
# close: 30.44796612 ma5: 30.177917639999997 ma10: 30.049644612
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 30.44796612 30.44796612
# self.Min 30.049644612 30.049644612
# self.Sum 90.675528372 90.675528372
# self.Cmp 1.0 1
# ---------- datetime 2021-01-19 ------------------
# close: 31.12308732 ma5: 30.474970968 ma10: 30.150912792000003
# close>ma5 True close>ma10 True ma5>ma10 True
# self.And 1.0 True
# self.Or 1.0 True
# self.If 1000.0 1000
# self.All 1.0 True
# self.Any 1.0 True
# self.Max 31.12308732 31.12308732
# self.Min 30.150912792000003 30.150912792000003
# self.Sum 91.74897108 91.74897108
# self.Cmp 1.0 1
# ---------- datetime 2021-01-20 ------------------
# close: 30.58299036 ma5: 30.609995207999997 ma10: 30.204922488
# close>ma5 False close>ma10 True ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 30.609995207999997 30.609995207999997
# self.Min 30.204922488 30.204922488
# self.Sum 91.397908056 91.397908056
# self.Cmp -1.0 -1
# ---------- datetime 2021-01-21 ------------------
# close: 30.31294188 ma5: 30.582990360000004 ma10: 30.252180972
# close>ma5 False close>ma10 True ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 30.582990360000004 30.582990360000004
# self.Min 30.252180972 30.252180972
# self.Sum 91.148113212 91.148113212
# self.Cmp -1.0 -1
# ---------- datetime 2021-01-22 ------------------
# close: 29.77284492 ma5: 30.44796612 ma10: 30.231927336000002
# close>ma5 False close>ma10 False ma5>ma10 True
# self.And 0.0 False
# self.Or 1.0 True
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 1.0 True
# self.Max 30.44796612 30.44796612
# self.Min 29.77284492 29.77284492
# self.Sum 90.452738376 90.452738376
# self.Cmp -1.0 -1
# ---------- datetime 2021-01-25 ------------------
# close: 28.96269948 ma5: 30.150912792000003 ma10: 30.164415216
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 30.164415216 30.164415216
# self.Min 28.96269948 28.96269948
# self.Sum 89.278027488 89.278027488
# self.Cmp -1.0 -1
# ---------- datetime 2021-01-26 ------------------
# close: 28.76016312 ma5: 29.678327952 ma10: 30.07664946
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 30.07664946 30.07664946
# self.Min 28.76016312 28.76016312
# self.Sum 88.515140532 88.515140532
# self.Cmp -1.0 -1
# ---------- datetime 2021-01-27 ------------------
# close: 28.89518736 ma5: 29.340767352 ma10: 29.97538128
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 29.97538128 29.97538128
# self.Min 28.89518736 28.89518736
# self.Sum 88.211335992 88.211335992
# self.Cmp -1.0 -1
# ---------- datetime 2021-01-28 ------------------
# close: 28.76016312 ma5: 29.0302116 ma10: 29.806600980000002
# close>ma5 False close>ma10 False ma5>ma10 False
# self.And 0.0 False
# self.Or 0.0 False
# self.If 5000.0 5000
# self.All 0.0 False
# self.Any 0.0 False
# self.Max 29.806600980000002 29.806600980000002
# self.Min 28.76016312 28.76016312
# self.Sum 87.5969757 87.5969757
# self.Cmp -1.0 -1

# %% [markdown]
# # 五、如何对齐不同周期的指标

# %%
# self.data0 是日度行情、self.data1 是月度行情
self.month = btind.xxx(self.data1) # 计算返回的 self.month 指标也是月度的
# 选择指标对象中的第一条 line 进行对齐
self.sellsignal = self.data0.close < self.month.lines[0]()
# 对齐整个指标对象
self.month_ = self.month() 
self.signal = self.data0.close < self.month_.lines[0] 

cerebro.run(runonce=False)

# %% [markdown]
# # 六、在 Backtrader 中调用 TA-Lib 库

# %%
class TALibStrategy(bt.Strategy):
    def __init__(self):
        # 计算 5 日均线
        bt.talib.SMA(self.data.close, timeperiod=5)
        bt.indicators.SMA(self.data, period=5)
        # 计算布林带
        bt.talib.BBANDS(self.data, timeperiod=25)
        bt.indicators.BollingerBands(self.data, period=25)

# %% [markdown]
# # 七、自定义新指标

# %%
class MyInd(bt.Indicator):
    lines = (xxx,xxx, ) # 最后一个 “,” 别省略
    params = ((xxx, n),) # 最后一个 “,” 别省略
    
    def __init__(self):
        '''可选'''
        pass
    
    def next(self):
        '''可选'''
        pass
    
    def once(self):
        '''可选'''
        pass 
    
    plotinfo = dict(...)
    plotlines = dict(...)
    ...

# %%
class DummyInd(bt.Indicator):
    # 将计算的指标命名为 'dummyline'，后面调用这根 line 的方式有： 
    # self.lines.dummyline ↔ self.l.dummyline ↔ self.dummyline
    lines = ('dummyline',)
    # 定义参数，后面调用这个参数的方式有：
    # self.params.xxx ↔ self.p.xxx
    params = (('value', 5),)
    
    def __init__(self):
        self.l.dummyline = bt.Max(0.0, self.p.value)
    
    def next(self):
        self.l.dummyline[0] = max(0.0, self.p.value)
   
    def once(self, start, end):
        dummy_array = self.l.dummyline.array
        for i in xrange(start, end):
            dummy_array[i] = max(0.0, self.p.value)

# %%
class My_MACD(bt.Indicator):
    lines = ('macd', 'signal', 'histo')
    params = (('period_me1',12), 
              ('period_me2', 26), 
              ('period_signal', 9),)
    def __init__(self):
        me1 = EMA(self.data, period=self.p.period_me1)
        me2 = EMA(self.data, period=self.p.period_me2)
        self.l.macd = me1 - me2
        self.l.signal = EMA(self.l.macd, period=self.p.period_signal)
        self.l.histo = self.l.macd - self.l.signal
